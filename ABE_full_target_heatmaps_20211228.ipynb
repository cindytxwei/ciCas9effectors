# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.rcParams.update({'font.family':'arial'})

from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LinearSegmentedColormap

# %matplotlib inline

# %%
df = pd.read_csv('Data/full_target/ABEmax_ABE16.csv',index_col=0)

df.columns = ['G1','G2','G3','A4','A5','T6','A7','A8','A9','T10',
              'C11','A12','T13','A14','G15','A16','A17','T18','C19','C20']

df = df*100

df
# Out:
#                                   G1         G2         G3         A4  \
# Batch
# 72hr_cellsonly_1           99.925266  99.925266  99.602727   0.326472
# 72hr_cellsonly_2           99.928661  99.902979  99.489214   0.370962
# 72hr_cellsonly_3           99.915988  99.891985  99.529934   0.300042
# 48hr_Cas9_ABE_ABE16_1      99.910003  99.892004  99.460019  18.129866
# 48hr_Cas9_ABE_ABE16_2      99.909581  99.877030  99.428551  18.051286
# 48hr_Cas9_ABE_ABE16_3      99.867539  99.854553  99.371461  18.531505
# 72hr_F22_ABE_ABE16_A115_1  99.914237  99.895178  98.008386   9.367257
# 72hr_F22_ABE_ABE16_A115_2  99.894264  99.881047  99.770024   9.941845
# 72hr_F22_ABE_ABE16_A115_3  99.887797  99.898483  98.984826   9.531951
#
#                                   A5        T6         A7        A8        A9  \
# Batch
# 72hr_cellsonly_1            0.270093  0.009180   0.150780  0.154714  0.175692
# 72hr_cellsonly_2            0.345280  0.008560   0.128410  0.159799  0.151238
# 72hr_cellsonly_3            0.294041  0.010001   0.146020  0.158022  0.152021
# 48hr_Cas9_ABE_ABE16_1      62.898798  0.000000  57.822976  2.150925  1.349953
# 48hr_Cas9_ABE_ABE16_2      61.933524  0.014467  57.029187  2.018156  0.922276
# 48hr_Cas9_ABE_ABE16_3      63.033089  0.005190  57.786608  2.189497  1.210327
# 72hr_F22_ABE_ABE16_A115_1  47.303221  0.000000  42.957881  1.972556  1.381742
# 72hr_F22_ABE_ABE16_A115_2  47.568068  0.013217  42.749141  2.006344  1.305842
# 72hr_F22_ABE_ABE16_A115_3  48.439838  0.010686  44.122676  2.217354  1.207523
#
#                                 T10       C11       A12       T13       A14  \
# Batch
# 72hr_cellsonly_1           0.007870  0.002620  0.180936  0.027534  0.123246
# 72hr_cellsonly_2           0.005710  0.014268  0.214017  0.022828  0.128410
# 72hr_cellsonly_3           0.012002  0.008000  0.130018  0.036005  0.136019
# 48hr_Cas9_ABE_ABE16_1      0.017999  0.013500  0.413985  0.049498  0.220492
# 48hr_Cas9_ABE_ABE16_2      0.010850  0.010850  0.332743  0.014467  0.162754
# 48hr_Cas9_ABE_ABE16_3      0.010389  0.007790  0.329853  0.033765  0.150642
# 72hr_F22_ABE_ABE16_A115_1  0.009530  0.000000  0.400229  0.066705  0.333524
# 72hr_F22_ABE_ABE16_A115_2  0.000000  0.005290  0.359503  0.015860  0.380650
# 72hr_F22_ABE_ABE16_A115_3  0.010686  0.032058  0.272494  0.021372  0.288523
#
#                                  G15       A16       A17       T18       C19  \
# Batch
# 72hr_cellsonly_1           99.892487  0.119313  0.123246  0.010489  0.006560
# 72hr_cellsonly_2           99.880151  0.122703  0.114142  0.005710  0.008560
# 72hr_cellsonly_3           99.887984  0.152021  0.114016  0.004000  0.006000
# 48hr_Cas9_ABE_ABE16_1      99.860505  0.166494  0.080997  0.000000  0.009000
# 48hr_Cas9_ABE_ABE16_2      99.822778  0.112120  0.126587  0.010850  0.003620
# 48hr_Cas9_ABE_ABE16_3      99.846761  0.150642  0.103891  0.002600  0.005190
# 72hr_F22_ABE_ABE16_A115_1  99.847532  0.104822  0.095293  0.009530  0.000000
# 72hr_F22_ABE_ABE16_A115_2  99.830822  0.108380  0.132170  0.005290  0.007930
# 72hr_F22_ABE_ABE16_A115_3  99.866424  0.160291  0.154948  0.000000  0.021372
#
#                                 C20
# Batch
# 72hr_cellsonly_1           0.031467
# 72hr_cellsonly_2           0.019975
# 72hr_cellsonly_3           0.034005
# 48hr_Cas9_ABE_ABE16_1      0.017999
# 48hr_Cas9_ABE_ABE16_2      0.050635
# 48hr_Cas9_ABE_ABE16_3      0.049348
# 72hr_F22_ABE_ABE16_A115_1  0.038117
# 72hr_F22_ABE_ABE16_A115_2  0.023791
# 72hr_F22_ABE_ABE16_A115_3  0.032058

# %%
df2 = df.div(df.A5, axis=0) * 100

df2
# Out:
#                                      G1            G2            G3  \
# Batch
# 72hr_cellsonly_1           36996.600617  36996.600617  36877.183164
# 72hr_cellsonly_2           28941.323916  28933.885899  28814.051197
# 72hr_cellsonly_3           33980.268139  33972.104896  33848.975654
# 48hr_Cas9_ABE_ABE16_1        158.842467    158.813850    158.127057
# 48hr_Cas9_ABE_ABE16_2        161.317449    161.264891    160.540762
# 48hr_Cas9_ABE_ABE16_3        158.436689    158.416086    157.649676
# 72hr_F22_ABE_ABE16_A115_1    211.220790    211.180500    207.191781
# 72hr_F22_ABE_ABE16_A115_2    210.002778    209.974993    209.741595
# 72hr_F22_ABE_ABE16_A115_3    206.210015    206.232076    204.345908
#
#                                    A4     A5        T6         A7         A8  \
# Batch
# 72hr_cellsonly_1           120.873765  100.0  3.398828  55.825232  57.281545
# 72hr_cellsonly_2           107.438017  100.0  2.479146  37.190085  46.280991
# 72hr_cellsonly_3           102.040802  100.0  3.401360  49.659844  53.741482
# 48hr_Cas9_ABE_ABE16_1       28.823866  100.0  0.000000  91.930176   3.419659
# 48hr_Cas9_ABE_ABE16_2       29.146228  100.0  0.023359  92.081289   3.258584
# 48hr_Cas9_ABE_ABE16_3       29.399646  100.0  0.008234  91.676625   3.473567
# 72hr_F22_ABE_ABE16_A115_1   19.802579  100.0  0.000000  90.813860   4.170024
# 72hr_F22_ABE_ABE16_A115_2   20.900250  100.0  0.027785  89.869408   4.217838
# 72hr_F22_ABE_ABE16_A115_3   19.677918  100.0  0.022060  91.087580   4.577542
#
#                                   A9       T10       C11        A12  \
# Batch
# 72hr_cellsonly_1           65.048533  2.913810  0.970036  66.990271
# 72hr_cellsonly_2           43.801643  1.653729  4.132238  61.983485
# 72hr_cellsonly_3           51.700680  4.081639  2.720707  44.217681
# 48hr_Cas9_ABE_ABE16_1       2.146230  0.028616  0.021462   0.658177
# 48hr_Cas9_ABE_ABE16_2       1.489138  0.017519  0.017519   0.537258
# 48hr_Cas9_ABE_ABE16_3       1.920145  0.016482  0.012359   0.523301
# 72hr_F22_ABE_ABE16_A115_1   2.921031  0.020147  0.000000   0.846092
# 72hr_F22_ABE_ABE16_A115_2   2.745207  0.000000  0.011121   0.755765
# 72hr_F22_ABE_ABE16_A115_3   2.492830  0.022060  0.066181   0.562541
#
#                                  T13        A14           G15        A16  \
# Batch
# 72hr_cellsonly_1           10.194189  45.631081  36984.464690  44.174768
# 72hr_cellsonly_2            6.611558  37.190085  28927.274341  35.537196
# 72hr_cellsonly_3           12.244883  46.258484  33970.744338  51.700680
# 48hr_Cas9_ABE_ABE16_1       0.078695   0.350551    158.763772   0.264702
# 48hr_Cas9_ABE_ABE16_2       0.023359   0.262789    161.177295   0.181032
# 48hr_Cas9_ABE_ABE16_3       0.053566   0.238988    158.403725   0.238988
# 72hr_F22_ABE_ABE16_A115_1   0.141015   0.705077    211.079774   0.221595
# 72hr_F22_ABE_ABE16_A115_2   0.033343   0.800222    209.869408   0.227841
# 72hr_F22_ABE_ABE16_A115_3   0.044121   0.595632    206.165894   0.330907
#
#                                  A17       T18       C19        C20
# Batch
# 72hr_cellsonly_1           45.631081  3.883513  2.428792  11.650501
# 72hr_cellsonly_2           33.057847  1.653729  2.479146   5.785128
# 72hr_cellsonly_3           38.775519  1.360354  2.040530  11.564638
# 48hr_Cas9_ABE_ABE16_1       0.128774  0.000000  0.014309   0.028616
# 48hr_Cas9_ABE_ABE16_2       0.204392  0.017519  0.005845   0.081757
# 48hr_Cas9_ABE_ABE16_3       0.164819  0.004125  0.008234   0.078289
# 72hr_F22_ABE_ABE16_A115_1   0.201450  0.020147  0.000000   0.080580
# 72hr_F22_ABE_ABE16_A115_2   0.277855  0.011121  0.016671   0.050014
# 72hr_F22_ABE_ABE16_A115_3   0.319876  0.000000  0.044121   0.066181

# %%
fig, (ax1, ax2) = plt.subplots(2,1,gridspec_kw={'height_ratios':[1,9]},figsize=(8,4))

#plt.setp(ax1.get_xticklabels(), visible=False)
fig.subplots_adjust(hspace=0)

ax1.set_ylim(-0.1,0.1)
ax1.set_xlim(-0.5,19.5)
ax2.set_xlim(-0.5,19.5)

ax1.axes.yaxis.set_visible(False)
ax1.axes.xaxis.set_visible(False)

ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.setp(ax2.spines.values(), color='grey')

ref = 'GGGAATAAATCATAGAATCC'
zero = [0] * len(df)

for x,nucleotide in enumerate(ref):
    if nucleotide == 'A':
        ax1.scatter(x,0,s=450,c='mediumseagreen',marker='s')
        ax1.text(x,0, 'A', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'C':
        ax1.scatter(x,0,s=450,c='royalblue',marker='s')
        ax1.text(x,0, 'C', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'G':
        ax1.scatter(x,0,s=450,c='gold',marker='s')
        ax1.text(x,0, 'G', ha='center',va='center',color='white',size=20)
        n = df.columns[x]
        df.drop(n,axis=1,inplace=False)
        df[n] = zero
    elif nucleotide == 'T':
        ax1.scatter(x,0,s=450,c='tomato',marker='s')
        ax1.text(x,0, 'T', ha='center',va='center',color='white',size=20)

cmap = LinearSegmentedColormap.from_list('mycmap', ['white', '#000099'])
masked_array = np.ma.masked_where(df < 0.7, df2)
cmap.set_bad(color='gainsboro')

g2 = ax2.imshow(masked_array,cmap=cmap,aspect="auto",interpolation='none',vmin=0,vmax=100)

cbar_ax = fig.add_axes([0.92, 0.12, 0.02, 0.68])
cbar = fig.colorbar(g2, cax=cbar_ax)
cbar.set_label('% of maximum\nA > G editing',fontsize=16)
cbar.ax.tick_params(labelsize=16)

ax2.set_xticks(np.arange(0, 20, 1))
ax2.set_xticklabels(np.arange(1, 21, 1), fontsize=14)
ax2.set_xticks(np.arange(-.5, 20, 1), minor=True)
ax2.set_yticks(np.arange(-.5, 9, 1), minor=True)
ax2.grid(which='minor', color='grey', linestyle='-', linewidth=0.75)

ax2.hlines([2.5,5.5], xmin=-0.5, xmax=19.5, color="black")

ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')

ytick_labels = ['','','control','','','ABEmax','','','ciABEmax']
ax2.set_yticklabels(labels = ytick_labels,
                    fontsize = 16)

ax1.set_title('ABEmax, ABE16', fontsize=20)

plt.savefig('ExportedPlots/20211228_ABEmax_ABE16_fulltarget_heatmap.pdf',dpi=300,bbox_inches='tight')
# Out:
# /var/folders/zt/rj0vk4w576n5lb6vjzgpk8nc0000gn/T/ipykernel_18230/4100405194.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels(labels = ytick_labels,

# %%
df = pd.read_csv('Data/full_target/ABE8e_ABE16.csv',index_col=0)

df.columns = ['G1','G2','G3','A4','A5','T6','A7','A8','A9','T10',
              'C11','A12','T13','A14','G15','A16','A17','T18','C19','C20']

df = df*100

df
# Out:
#                                  G1         G2         G3         A4  \
# Batch
# 72hr_cellsonly_1          99.925266  99.925266  99.602727   0.326472
# 72hr_cellsonly_2          99.928661  99.902979  99.489214   0.370962
# 72hr_cellsonly_3          99.915988  99.891985  99.529934   0.300042
# 48hr_Cas9_8e_ABE16_1      99.884174  99.888035  99.438246  65.184742
# 48hr_Cas9_8e_ABE16_2      99.895213  99.898207  99.506003  65.644741
# 48hr_Cas9_8e_ABE16_3      99.876474  99.863047  99.489782  67.104380
# 72hr_F22_8e_ABE16_A115_1  99.925730  99.893438  98.614699  38.239473
# 72hr_F22_8e_ABE16_A115_2  99.917973  99.891079  99.033160  41.786569
# 72hr_F22_8e_ABE16_A115_3  99.883277  99.859932  98.981077  40.559172
#
#                                  A5        T6         A7         A8  \
# Batch
# 72hr_cellsonly_1           0.270093  0.009180   0.150780   0.154714
# 72hr_cellsonly_2           0.345280  0.008560   0.128410   0.159799
# 72hr_cellsonly_3           0.294041  0.010001   0.146020   0.158022
# 48hr_Cas9_8e_ABE16_1      66.460754  0.023165  66.578510  32.357824
# 48hr_Cas9_8e_ABE16_2      67.198587  0.020958  67.114757  32.570881
# 48hr_Cas9_8e_ABE16_3      68.500765  0.024168  68.532990  34.063750
# 72hr_F22_8e_ABE16_A115_1  39.240506  0.025833  39.628003  13.894988
# 72hr_F22_8e_ABE16_A115_2  42.855606  0.006720  43.096307  14.643789
# 72hr_F22_8e_ABE16_A115_3  41.589080  0.013732  41.762105  14.054819
#
#                                  A9       T10       C11        A12       T13  \
# Batch
# 72hr_cellsonly_1           0.175692  0.007870  0.002620   0.180936  0.027534
# 72hr_cellsonly_2           0.151238  0.005710  0.014268   0.214017  0.022828
# 72hr_cellsonly_3           0.152021  0.012002  0.008000   0.130018  0.036005
# 48hr_Cas9_8e_ABE16_1      10.134744  0.021235  0.036678  13.179028  0.036678
# 48hr_Cas9_8e_ABE16_2      10.568546  0.008980  0.032933  13.080447  0.029939
# 48hr_Cas9_8e_ABE16_3      11.090523  0.010741  0.029539  13.289831  0.037595
# 72hr_F22_8e_ABE16_A115_1   4.698398  0.006460  0.022604  11.146990  0.016146
# 72hr_F22_8e_ABE16_A115_2   4.940430  0.010758  0.016136  12.905091  0.021515
# 72hr_F22_8e_ABE16_A115_3   4.667546  0.013732  0.021971  11.721732  0.024718
#
#                                A14        G15       A16       A17       T18  \
# Batch
# 72hr_cellsonly_1          0.123246  99.892487  0.119313  0.123246  0.010489
# 72hr_cellsonly_2          0.128410  99.880151  0.122703  0.114142  0.005710
# 72hr_cellsonly_3          0.136019  99.887984  0.152021  0.114016  0.004000
# 48hr_Cas9_8e_ABE16_1      2.225783  99.828192  0.142852  0.131269  0.007720
# 48hr_Cas9_8e_ABE16_2      2.374180  99.850304  0.182629  0.158678  0.002990
# 48hr_Cas9_8e_ABE16_3      2.317463  99.863047  0.115470  0.134268  0.008060
# 72hr_F22_8e_ABE16_A115_1  4.772669  99.890209  0.148540  0.119478  0.006460
# 72hr_F22_8e_ABE16_A115_2  5.485034  99.848049  0.121023  0.135815  0.002690
# 72hr_F22_8e_ABE16_A115_3  5.503831  99.802258  0.126335  0.127709  0.002750
#
#                                C19       C20
# Batch
# 72hr_cellsonly_1          0.006560  0.031467
# 72hr_cellsonly_2          0.008560  0.019975
# 72hr_cellsonly_3          0.006000  0.034005
# 48hr_Cas9_8e_ABE16_1      0.013513  0.040539
# 48hr_Cas9_8e_ABE16_2      0.005990  0.017964
# 48hr_Cas9_8e_ABE16_3      0.005370  0.048336
# 72hr_F22_8e_ABE16_A115_1  0.009690  0.025833
# 72hr_F22_8e_ABE16_A115_2  0.008070  0.020171
# 72hr_F22_8e_ABE16_A115_3  0.009610  0.019225

# %%
df2 = df.div(df.A5, axis=0) * 100

df2
# Out:
#                                     G1            G2            G3  \
# Batch
# 72hr_cellsonly_1          36996.600617  36996.600617  36877.183164
# 72hr_cellsonly_2          28941.323916  28933.885899  28814.051197
# 72hr_cellsonly_3          33980.268139  33972.104896  33848.975654
# 48hr_Cas9_8e_ABE16_1        150.290461    150.296270    149.619496
# 48hr_Cas9_8e_ABE16_2        148.656716    148.661172    148.077523
# 48hr_Cas9_8e_ABE16_3        145.803442    145.783841    145.238935
# 72hr_F22_8e_ABE16_A115_1    254.649441    254.567150    251.308427
# 72hr_F22_8e_ABE16_A115_2    233.150298    233.087543    231.085660
# 72hr_F22_8e_ABE16_A115_3    240.167074    240.110942    237.997755
#
#                                   A4     A5        T6          A7         A8  \
# Batch
# 72hr_cellsonly_1          120.873765  100.0  3.398828   55.825232  57.281545
# 72hr_cellsonly_2          107.438017  100.0  2.479146   37.190085  46.280991
# 72hr_cellsonly_3          102.040802  100.0  3.401360   49.659844  53.741482
# 48hr_Cas9_8e_ABE16_1       98.080051  100.0  0.034855  100.177181  48.687115
# 48hr_Cas9_8e_ABE16_2       97.687681  100.0  0.031187   99.875251  48.469592
# 48hr_Cas9_8e_ABE16_3       97.961504  100.0  0.035282  100.047042  49.727547
# 72hr_F22_8e_ABE16_A115_1   97.448980  100.0  0.065833  100.987492  35.409809
# 72hr_F22_8e_ABE16_A115_2   97.505491  100.0  0.015681  100.561657  34.170066
# 72hr_F22_8e_ABE16_A115_3   97.523608  100.0  0.033019  100.416034  33.794493
#
#                                  A9       T10       C11        A12        T13  \
# Batch
# 72hr_cellsonly_1          65.048533  2.913810  0.970036  66.990271  10.194189
# 72hr_cellsonly_2          43.801643  1.653729  4.132238  61.983485   6.611558
# 72hr_cellsonly_3          51.700680  4.081639  2.720707  44.217681  12.244883
# 48hr_Cas9_8e_ABE16_1      15.249216  0.031951  0.055188  19.829790   0.055188
# 48hr_Cas9_8e_ABE16_2      15.727334  0.013363  0.049009  19.465360   0.044553
# 48hr_Cas9_8e_ABE16_3      16.190364  0.015681  0.043122  19.400996   0.054883
# 72hr_F22_8e_ABE16_A115_1  11.973338  0.016463  0.057604  28.406847   0.041145
# 72hr_F22_8e_ABE16_A115_2  11.528083  0.025102  0.037653  30.112959   0.050204
# 72hr_F22_8e_ABE16_A115_3  11.223007  0.033019  0.052830  28.184640   0.059433
#
#                                 A14           G15        A16        A17  \
# Batch
# 72hr_cellsonly_1          45.631081  36984.464690  44.174768  45.631081
# 72hr_cellsonly_2          37.190085  28927.274341  35.537196  33.057847
# 72hr_cellsonly_3          46.258484  33970.744338  51.700680  38.775519
# 48hr_Cas9_8e_ABE16_1       3.349018    150.206228   0.214941   0.197514
# 48hr_Cas9_8e_ABE16_2       3.533081    148.589886   0.271776   0.236133
# 48hr_Cas9_8e_ABE16_3       3.383120    145.783841   0.168568   0.196009
# 72hr_F22_8e_ABE16_A115_1  12.162607    254.558920   0.378538   0.304477
# 72hr_F22_8e_ABE16_A115_2  12.798870    232.987135   0.282397   0.316913
# 72hr_F22_8e_ABE16_A115_3  13.233838    239.972265   0.303771   0.307073
#
#                                T18       C19        C20
# Batch
# 72hr_cellsonly_1          3.883513  2.428792  11.650501
# 72hr_cellsonly_2          1.653729  2.479146   5.785128
# 72hr_cellsonly_3          1.360354  2.040530  11.564638
# 48hr_Cas9_8e_ABE16_1      0.011616  0.020332   0.060997
# 48hr_Cas9_8e_ABE16_2      0.004449  0.008914   0.026732
# 48hr_Cas9_8e_ABE16_3      0.011766  0.007839   0.070563
# 72hr_F22_8e_ABE16_A115_1  0.016463  0.024694   0.065833
# 72hr_F22_8e_ABE16_A115_2  0.006277  0.018831   0.047066
# 72hr_F22_8e_ABE16_A115_3  0.006612  0.023107   0.046226

# %%
fig, (ax1, ax2) = plt.subplots(2,1,gridspec_kw={'height_ratios':[1,9]},figsize=(8,4))

#plt.setp(ax1.get_xticklabels(), visible=False)
fig.subplots_adjust(hspace=0)

ax1.set_ylim(-0.1,0.1)
ax1.set_xlim(-0.5,19.5)
ax2.set_xlim(-0.5,19.5)

ax1.axes.yaxis.set_visible(False)
ax1.axes.xaxis.set_visible(False)

ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.setp(ax2.spines.values(), color='grey')

ref = 'GGGAATAAATCATAGAATCC'
zero = [0] * len(df)

for x,nucleotide in enumerate(ref):
    if nucleotide == 'A':
        ax1.scatter(x,0,s=450,c='mediumseagreen',marker='s')
        ax1.text(x,0, 'A', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'C':
        ax1.scatter(x,0,s=450,c='royalblue',marker='s')
        ax1.text(x,0, 'C', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'G':
        ax1.scatter(x,0,s=450,c='gold',marker='s')
        ax1.text(x,0, 'G', ha='center',va='center',color='white',size=20)
        n = df.columns[x]
        df.drop(n,axis=1,inplace=False)
        df[n] = zero
    elif nucleotide == 'T':
        ax1.scatter(x,0,s=450,c='tomato',marker='s')
        ax1.text(x,0, 'T', ha='center',va='center',color='white',size=20)

cmap = LinearSegmentedColormap.from_list('mycmap', ['white', '#000099'])
masked_array = np.ma.masked_where(df < 0.7, df2)
cmap.set_bad(color='gainsboro')

g2 = ax2.imshow(masked_array,cmap=cmap,aspect="auto",interpolation='none',vmin=0,vmax=100)

cbar_ax = fig.add_axes([0.92, 0.12, 0.02, 0.68])
cbar = fig.colorbar(g2, cax=cbar_ax)
cbar.set_label('% of maximum\nA > G editing',fontsize=16)
cbar.ax.tick_params(labelsize=16)

ax2.set_xticks(np.arange(0, 20, 1))
ax2.set_xticklabels(np.arange(1, 21, 1), fontsize=14)
ax2.set_xticks(np.arange(-.5, 20, 1), minor=True)
ax2.set_yticks(np.arange(-.5, 9, 1), minor=True)
ax2.grid(which='minor', color='grey', linestyle='-', linewidth=0.75)

ax2.hlines([2.5,5.5], xmin=-0.5, xmax=19.5, color="black")

ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')

ytick_labels = ['','','control','','','ABE8e','','','ciABE8e']
ax2.set_yticklabels(labels = ytick_labels,
                    fontsize = 16)

ax1.set_title('ABE8e, ABE16', fontsize=20)

plt.savefig('ExportedPlots/20211228_ABE8e_ABE16_fulltarget_heatmap.pdf',dpi=300,bbox_inches='tight')
# Out:
# /var/folders/zt/rj0vk4w576n5lb6vjzgpk8nc0000gn/T/ipykernel_18230/2649213496.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels(labels = ytick_labels,
