# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

plt.rcParams.update({'font.family':'arial'})

# %matplotlib inline

# %% [markdown]
# # ABE9

# %%
df_A115 = pd.read_csv('Data/ABE8e_ABE9_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABE8e_ABE9_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABE8e_ABE9_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABE8e_ABE9_DMSO_sem.csv')

df_A115
# Out:
#    time        A2        A3        A5        A8        A9       A12       A14  \
# 0     0  0.337585  0.325968  0.424606  0.245636  0.263238  0.225136  0.224768
# 1     1  0.345904  0.346798  0.480235  0.243275  0.257801  0.195307  0.208758
# 2     2  0.343932  0.347827  1.205199  0.328370  0.283953  0.230259  0.208272
# 3     4  0.382242  0.392072  2.425429  0.757077  0.317237  0.266353  0.253730
# 4     8  0.342075  0.513488  4.157850  1.739999  0.407996  0.324482  0.359796
# 5    12  0.388229  0.664801  5.460409  2.689187  0.549937  0.470124  0.599723
# 6    24  0.380875  0.857077  6.796931  3.804313  0.739685  0.631745  0.634645
#
#         A16
# 0  0.271493
# 1  0.257989
# 2  0.275175
# 3  0.312515
# 4  0.268912
# 5  0.316365
# 6  0.270295

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A3'],yerr=df_DMSO_SEM['A3'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A3'],yerr=df_A115_SEM['A3'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.3, 1.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(5, 1.2, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 1.2, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.4, 1.2, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_ABE9_A3_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A5'],yerr=df_DMSO_SEM['A5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A5'],yerr=df_A115_SEM['A5'],fmt='-o',color='black')

ax.set_ylim([-0.5,8.5])
ax.set_yticks([0,2,4,6,8])
ax.set_yticklabels([0,2,4,6,8],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.3, 8.5, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 8.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 8.5, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 8.5, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(7.7, 8.5, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 8.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.4, 8.5, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_ABE9_A5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.1,4.5])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels([0,1,2,3,4],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.3, 4.5, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 4.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 4.5, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 4.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 4.5, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 4.5, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(16.4, 4.5, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_ABE9_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # ABE16

# %%
df_A115 = pd.read_csv('Data/ABE8e_ABE16_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABE8e_ABE16_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABE8e_ABE16_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABE8e_ABE16_DMSO_sem.csv')

df_A115
# Out:
#    time         A4         A5         A7        A8        A9       A12  \
# 0     0   1.210792   1.309598   1.077149  0.247710  0.161491  0.230977
# 1     1   1.325029   1.456716   1.250422  0.242401  0.201252  0.243774
# 2     2   1.690032   1.943196   1.649984  0.314439  0.228471  0.310285
# 3     4   3.139716   3.476515   3.243167  0.478232  0.255185  0.438040
# 4     8   7.600295   7.924035   7.744459  1.503315  0.496115  1.251014
# 5    12  11.693941  11.820852  11.818525  2.956950  0.990326  2.445718
# 6    24  20.067246  20.323133  20.249936  6.901535  2.410540  4.928608
#
#         A14       A16       A17
# 0  0.140815  0.140243  0.148194
# 1  0.153830  0.136474  0.130299
# 2  0.217810  0.159844  0.177316
# 3  0.201134  0.166707  0.143383
# 4  0.329451  0.150878  0.140850
# 5  0.576592  0.165365  0.158898
# 6  1.123073  0.124895  0.111232

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A4'],yerr=df_DMSO_SEM['A4'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A4'],yerr=df_A115_SEM['A4'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 27, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(6.8, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 27, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.6, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 27, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_ABE16_A4_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A5'],yerr=df_DMSO_SEM['A5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A5'],yerr=df_A115_SEM['A5'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 27, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.8, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(7.7, 27, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.6, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 27, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_ABE16_A5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A7'],yerr=df_DMSO_SEM['A7'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A7'],yerr=df_A115_SEM['A7'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 27, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.8, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 27, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(9.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.6, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 27, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_ABE16_A7_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.1,8.2])
ax.set_yticks([0,2,4,6,8])
ax.set_yticklabels([0,2,4,6,8],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 8.2, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 8.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.8, 8.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 8.2, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 8.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.5, 8.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(10.6, 8.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 8.2, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_ABE16_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # HEK2

# %%
df_A115 = pd.read_csv('Data/ABE8e_HEK2_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABE8e_HEK2_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABE8e_HEK2_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABE8e_HEK2_DMSO_sem.csv')

df_A115
# Out:
#    time        A2        A3         A5         A7        A8        A9  \
# 0     0  0.279252  0.406515   1.656360   1.315677  0.308014  0.296124
# 1     1  0.279921  0.418430   2.478236   1.607257  0.295688  0.260684
# 2     2  0.322302  0.515223   3.265759   1.973740  0.408584  0.326544
# 3     4  0.268516  0.604454   5.674007   4.317458  0.458116  0.306039
# 4     8  0.308158  1.046737  10.910709   9.792059  0.925638  0.524698
# 5    12  0.308992  1.775852  14.419642  13.503357  1.624693  0.828982
# 6    24  0.347113  3.573625  21.874337  21.029667  3.256770  1.478504
#
#         A12       A14       A16
# 0  0.325275  0.224044  0.218445
# 1  0.306997  0.203739  0.217131
# 2  0.384459  0.223835  0.241832
# 3  0.412655  0.231854  0.235253
# 4  0.692824  0.259867  0.237226
# 5  1.041226  0.341573  0.235828
# 6  2.034707  0.452955  0.230747

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A3'],yerr=df_DMSO_SEM['A3'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A3'],yerr=df_A115_SEM['A3'],fmt='-o',color='black')

ax.set_ylim([-0.1,4.2])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels([0,1,2,3,4],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 4.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 4.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(5, 4.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 4.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 4.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 4.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK2_A3_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A5'],yerr=df_DMSO_SEM['A5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A5'],yerr=df_A115_SEM['A5'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 27, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 27, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(7.2, 27, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 27, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 27, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK2_A5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A7'],yerr=df_DMSO_SEM['A7'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A7'],yerr=df_A115_SEM['A7'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 27, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 27, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 27, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(9.35, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 27, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 27, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK2_A7_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.1,4.2])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels([0,1,2,3,4],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 4.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 4.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 4.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 4.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(10.4, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 4.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 4.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK2_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A9'],yerr=df_DMSO_SEM['A9'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A9'],yerr=df_A115_SEM['A9'],fmt='-o',color='black')

ax.set_ylim([-0.1,2.2])
ax.set_yticks([0.0,0.5,1.0,1.5,2.0])
ax.set_yticklabels([0.0,0.5,1.0,1.5,2.0],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 2.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 2.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 2.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 2.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(12.1, 2.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 2.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK2_A9_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A12'],yerr=df_DMSO_SEM['A12'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A12'],yerr=df_A115_SEM['A12'],fmt='-o',color='black')

ax.set_ylim([-0.1,2.2])
ax.set_yticks([0.0,0.5,1.0,1.5,2.0])
ax.set_yticklabels([0.0,0.5,1.0,1.5,2.0],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 2.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 2.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 2.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 2.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 2.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 2.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(18.5, 2.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK2_A12_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # HEK3

# %%
df_A115 = pd.read_csv('Data/ABE8e_HEK3_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABE8e_HEK3_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABE8e_HEK3_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABE8e_HEK3_DMSO_sem.csv')

df_A115
# Out:
#    time         A6         A8       A12       A15       A20
# 0     0   9.933375   3.152898  0.616803  0.196632  0.277655
# 1     1  11.769623   3.873827  0.721224  0.251806  0.267213
# 2     2  12.673707   4.027523  0.813628  0.252688  0.266144
# 3     4  14.869745   5.243385  0.831712  0.226905  0.267852
# 4     8  17.494345   9.277625  1.359013  0.294345  0.303909
# 5    12  17.851627  10.890649  1.581350  0.366579  0.312106
# 6    24  24.171504  19.631741  3.176983  0.489794  0.279839

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A6'],yerr=df_DMSO_SEM['A6'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A6'],yerr=df_A115_SEM['A6'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.8, 27, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(8.3, 27, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(11.5, 27, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.7, 27, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK3_A6_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.8, 27, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.3, 27, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(11.5, 27, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.7, 27, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK3_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A12'],yerr=df_DMSO_SEM['A12'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A12'],yerr=df_A115_SEM['A12'],fmt='-o',color='black')

ax.set_ylim([-0.1,4.2])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels([0,1,2,3,4],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.8, 4.2, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.3, 4.2, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 4.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(11.5, 4.2, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 4.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(18.7, 4.2, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABE8e, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABE8e_HEK3_A12_20211109.svg',dpi=300,bbox_inches='tight')
