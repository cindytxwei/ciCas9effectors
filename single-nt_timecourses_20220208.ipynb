# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

plt.rcParams.update({'font.family':'arial'})

# %matplotlib inline

# %% [markdown]
# # 4A) BE4max cumulative nucleotide editing time courses

# %% [markdown]
# ABE9

# %%
df_A115 = pd.read_csv('data/BE4max_ABE9_A115.csv')
df_SEM = pd.read_csv('data/BE4max_ABE9_A115_sem.csv')

df_A115
# Out:
#    time        C6        C7       C17       C20
# 0     0  0.106696  0.104548  0.048108  0.175950
# 1     1  0.080213  0.078356  0.044346  0.125959
# 2     2  0.132439  0.125962  0.054639  0.152943
# 3     4  0.409641  0.390562  0.050433  0.162707
# 4     8  0.785253  0.787527  0.046692  0.133680
# 5    12  1.181045  1.176583  0.058528  0.138829
# 6    24  1.937328  1.925065  0.054012  0.146342

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_A115['time'],df_A115['C6'],yerr=df_SEM['C6'],fmt='-o',color='darkgreen')
ax.errorbar(df_A115['time'],df_A115['C7'],yerr=df_SEM['C7'],fmt='-o',color='blue')

ax.set_ylim([-0.2,2.2])
ax.set_yticks([0,0.5,1,1.5,2])
ax.set_yticklabels([0,0.5,1,1.5,2],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(4, 2.3, 'GAAGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 2.3, 'C', ha='center', va='bottom',color='darkgreen',fontsize=18)
ax.text(8.3, 2.3, 'C', ha='center', va='bottom',color='blue',fontsize=18)
ax.text(15.8, 2.3, 'AAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 2.3, 'GAAGACCAAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.8, 2.2, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.9, 2.2, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.9, 2.2, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.05, 2.2, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.15, 2.2, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.25, 2.2, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.35, 2.2, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.45, 2.2, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.45, 2.2, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.55, 2.2, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.73, 2.2, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.8, 2.2, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.75, 2.2, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.63, 2.2, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.75, 2.2, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.85, 2.2, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.95, 2.2, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20, 2.2, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.1, 2.2, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.25, 2.2, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciBE4max, ABE9',fontsize=20,pad=30)

plt.savefig('ExportedPlots/BE4max_ABE9_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# EMX1

# %%
df_A115 = pd.read_csv('data/BE4max_EMX1_A115.csv')
df_SEM = pd.read_csv('data/BE4max_EMX1_A115_sem.csv')

df_A115
# Out:
#    time         C5        C6
# 0     0   0.099162  0.145475
# 1     1   0.190589  0.184389
# 2     2   0.419613  0.255783
# 3     4   1.408131  0.984705
# 4     8   3.565656  2.949746
# 5    12   6.025124  5.132520
# 6    24  10.168713  8.892265

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_A115['time'],df_A115['C5'],yerr=df_SEM['C5'],fmt='-o',color='orange')
ax.errorbar(df_A115['time'],df_A115['C6'],yerr=df_SEM['C6'],fmt='-o',color='darkgreen')

ax.set_ylim([-0.5,11])
ax.set_yticks([0,2,4,6,8,10])
ax.set_yticklabels([0,2,4,6,8,10],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(3.2, 11.5, 'GAGT', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.9, 11.5, 'C', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(7, 11.5, 'C', ha='center', va='bottom',color='darkgreen',fontsize=18)
ax.text(15.3, 11.5, 'GAGCAGAAGAAGAA', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 11.5, 'GAGTCCGAGCAGAAGAAGAA', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.6, 11, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.7, 11, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.8, 11, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(4.8, 11, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.9, 11, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.05, 11, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.23, 11, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.33, 11, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.5, 11, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.6, 11, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.73, 11, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.8, 11, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.9, 11, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.9, 11, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.05, 11, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.15, 11, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.25, 11, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.35, 11, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.45, 11, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.55, 11, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciBE4max, EMX1',fontsize=20,pad=30)

plt.savefig('ExportedPlots/BE4max_EMX1_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# HEK2

# %%
df_A115 = pd.read_csv('data/BE4max_HEK2_A115.csv')
df_SEM = pd.read_csv('data/BE4max_HEK2_A115_sem.csv')

df_A115
# Out:
#    time         C4         C6       C11       C17       C20
# 0     0   0.156617   0.291003  0.129016  0.035420  0.268163
# 1     1   0.166675   0.414032  0.105082  0.055344  0.248275
# 2     2   0.310742   1.099354  0.128074  0.056569  0.255642
# 3     4   1.116808   3.564691  0.134052  0.054385  0.258071
# 4     8   4.402116   8.955606  0.128891  0.059238  0.239508
# 5    12   6.979514  12.163620  0.135689  0.060570  0.268978
# 6    24  12.421269  19.128249  0.134785  0.048448  0.251045

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_A115['time'],df_A115['C4'],yerr=df_SEM['C4'],fmt='-o',color='red')
ax.errorbar(df_A115['time'],df_A115['C6'],yerr=df_SEM['C6'],fmt='-o',color='darkgreen')

ax.set_ylim([-0.5,20.5])
ax.set_yticks([0,5,10,15,20])
ax.set_yticklabels([0,5,10,15,20],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(3, 21.5, 'GAA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.1, 21.5, 'C', ha='center', va='bottom',color='red',fontsize=18)
ax.text(6.2, 21.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 21.5, 'C', ha='center', va='bottom',color='darkgreen',fontsize=18)
ax.text(15.2, 21.5, 'AAAGCATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 21.5, 'GAACACAAAGCATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.9, 20.5, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3, 20.5, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(4, 20.5, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.1, 20.5, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.15, 20.5, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.2, 20.5, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.3, 20.5, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.33, 20.5, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.4, 20.5, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.45, 20.5, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.65, 20.5, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.7, 20.5, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.65, 20.5, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.55, 20.5, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.6, 20.5, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.7, 20.5, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.85, 20.5, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.9, 20.5, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.9, 20.5, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22, 20.5, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciBE4max, HEK2',fontsize=20,pad=30)

plt.savefig('ExportedPlots/BE4max_HEK2_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# HEK3

# %%
df_A115 = pd.read_csv('data/BE4max_HEK3_A115.csv')
df_SEM = pd.read_csv('data/BE4max_HEK3_A115_sem.csv')

df_A115
# Out:
#    time        C3         C4         C5        C9       C14       C16
# 0     0  0.204039   0.499274   0.888237  0.163390  0.276704  0.146986
# 1     1  0.135013   0.504682   0.997594  0.146977  0.202027  0.128888
# 2     2  0.156356   0.675374   1.388417  0.151426  0.235415  0.132128
# 3     4  0.185284   1.598684   3.610869  0.360078  0.185108  0.112804
# 4     8  0.326116   5.479565   9.358634  0.882266  0.251817  0.152833
# 5    12  0.371317   9.377924  13.452151  1.575887  0.219266  0.145055
# 6    24  0.667873  21.441333  27.397161  3.775435  0.236898  0.173432

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_A115['time'],df_A115['C3'],yerr=df_SEM['C3'],fmt='-o',color='dimgrey')
ax.errorbar(df_A115['time'],df_A115['C4'],yerr=df_SEM['C4'],fmt='-o',color='red')
ax.errorbar(df_A115['time'],df_A115['C5'],yerr=df_SEM['C5'],fmt='-o',color='orange')
ax.errorbar(df_A115['time'],df_A115['C9'],yerr=df_SEM['C9'],fmt='-o',color='rebeccapurple')

ax.set_ylim([-0.5,30])
ax.set_yticks([0,5,10,15,20,25,30])
ax.set_yticklabels([0,5,10,15,20,25,30],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(2.1, 31.5, 'GG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.8, 31.5, 'C', ha='center', va='bottom',color='dimgrey',fontsize=18)
ax.text(4.9, 31.5, 'C', ha='center', va='bottom',color='red',fontsize=18)
ax.text(6, 31.5, 'C', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(8.2, 31.5, 'AGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 31.5, 'C', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(17.1, 31.5, 'TGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 31.5, 'GGCCCAGACTGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.5, 30, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.75, 30, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.85, 30, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5, 30, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.1, 30, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.15, 30, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.2, 30, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.33, 30, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.5, 30, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.5, 30, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.55, 30, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.6, 30, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.7, 30, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.9, 30, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17, 30, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.1, 30, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.2, 30, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.3, 30, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.4, 30, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.55, 30, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciBE4max, HEK3',fontsize=20,pad=30)

plt.savefig('ExportedPlots/BE4max_HEK3_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # 4B) ciABEmax cumulative nucleotide time courses

# %% [markdown]
# ABE9

# %%
df_max_A115 = pd.read_csv('data/ABEmax_ABE9_A115.csv')
df_max_SEM = pd.read_csv('data/ABEmax_ABE9_A115_sem.csv')

df_max_A115
# Out:
#    time        A2        A3        A5        A8        A9       A12       A14  \
# 0     0  0.358569  0.354975  0.395391  0.233220  0.265664  0.228197  0.219255
# 1     1  0.350241  0.368490  0.451735  0.237047  0.250999  0.225024  0.227754
# 2     2  0.343201  0.337960  0.762624  0.236606  0.272299  0.225425  0.217741
# 3     4  0.319464  0.320110  1.456314  0.213129  0.235157  0.189793  0.212592
# 4     8  0.335909  0.301736  3.462152  0.232317  0.249113  0.194135  0.183249
# 5    12  0.388636  0.373942  4.522228  0.261204  0.307354  0.240697  0.251807
# 6    24  0.346727  0.326956  7.189869  0.345514  0.306686  0.228406  0.208398
#
#         A16
# 0  0.267620
# 1  0.305035
# 2  0.316549
# 3  0.279489
# 4  0.252264
# 5  0.303891
# 6  0.275031

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_max_A115['time'],df_max_A115['A3'],yerr=df_max_SEM['A3'],fmt='-o',color='dimgrey',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A5'],yerr=df_max_SEM['A5'],fmt='-o',color='orange',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A8'],yerr=df_max_SEM['A8'],fmt='-o',color='rebeccapurple',markersize=6)

ax.set_ylim([-0.5,8.5])
ax.set_yticks([0,2,4,6,8])
ax.set_yticklabels([0,2,4,6,8],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(2.3, 9, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 9, 'A', ha='center', va='bottom',color='dimgrey',fontsize=18)
ax.text(5, 9, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 9, 'A', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(7.7, 9, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 9, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(16.4, 9, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 9, 'GAAGACCAAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.8, 8.6, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.9, 8.6, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.9, 8.6, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.05, 8.6, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.15, 8.6, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.25, 8.6, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.35, 8.6, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.45, 8.6, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.45, 8.6, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.55, 8.6, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.73, 8.6, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.8, 8.6, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.75, 8.6, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.63, 8.6, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.75, 8.6, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.85, 8.6, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.95, 8.6, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20, 8.6, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.1, 8.6, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.25, 8.6, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABEmax, ABE9',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABEmax_ABE9_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# ABE16

# %%
df_max_A115 = pd.read_csv('data/ABEmax_ABE16_A115.csv')
df_max_SEM = pd.read_csv('data/ABEmax_ABE16_A115_sem.csv')

df_max_A115
# Out:
#    time        A4         A5         A7        A8        A9       A12  \
# 0     0  0.279726   2.319232   0.786641  0.168519  0.153396  0.168881
# 1     1  0.292358   2.429489   0.662951  0.177479  0.143018  0.169173
# 2     2  0.370645   4.579123   1.234754  0.173311  0.127524  0.167055
# 3     4  0.431492   8.496818   1.794260  0.189206  0.180145  0.185136
# 4     8  0.870147  14.207716   5.434250  0.298291  0.234171  0.183785
# 5    12  1.696255  17.583705   9.959812  0.389748  0.305014  0.242809
# 6    24  4.623897  24.491393  19.594813  0.755758  0.611430  0.248907
#
#         A14       A16       A17
# 0  0.168147  0.137147  0.147051
# 1  0.153183  0.117268  0.123067
# 2  0.163179  0.124245  0.120636
# 3  0.163510  0.144350  0.126696
# 4  0.146995  0.157322  0.131004
# 5  0.160207  0.146182  0.129592
# 6  0.194270  0.125895  0.125887

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_max_A115['time'],df_max_A115['A4'],yerr=df_max_SEM['A4'],fmt='-o',color='red',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A5'],yerr=df_max_SEM['A5'],fmt='-o',color='orange',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A7'],yerr=df_max_SEM['A7'],fmt='-o',color='blue',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A8'],yerr=df_max_SEM['A8'],fmt='-o',color='rebeccapurple',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A9'],yerr=df_max_SEM['A9'],fmt='-o',color='hotpink',markersize=6)

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(3.5, 28.5, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 28.5, 'A', ha='center', va='bottom',color='red',fontsize=18)
ax.text(6.8, 28.5, 'A', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(7.7, 28.5, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 28.5, 'A', ha='center', va='bottom',color='blue',fontsize=18)
ax.text(9.5, 28.5, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(10.6, 28.5, 'A', ha='center', va='bottom',color='hotpink',fontsize=18)
ax.text(16.6, 28.5, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 28.5, 'GGGAATAAATCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(2.25, 27.3, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.5, 27.3, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(4.65, 27.3, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.75, 27.3, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.85, 27.3, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.75, 27.3, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.55, 27.3, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.55, 27.3, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.65, 27.3, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.55, 27.3, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.55, 27.3, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.55, 27.3, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.5, 27.3, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.45, 27.3, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.45, 27.3, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.5, 27.3, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.5, 27.3, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.5, 27.3, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.5, 27.3, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.6, 27.3, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABEmax, ABE16',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABEmax_ABE16_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# HEK2

# %%
df_max_A115 = pd.read_csv('data/ABEmax_HEK2_A115.csv')
df_max_SEM = pd.read_csv('data/ABEmax_HEK2_A115_sem.csv')

df_max_A115
# Out:
#    time        A2        A3         A5        A7        A8        A9  \
# 0     0  0.280169  0.307123   2.909596  0.444721  0.229205  0.256242
# 1     1  0.257553  0.303324   3.706076  0.449062  0.219951  0.233345
# 2     2  0.331825  0.379255   5.475038  0.528234  0.296191  0.315258
# 3     4  0.290838  0.341137   7.590695  0.618457  0.255224  0.265429
# 4     8  0.255478  0.311876  13.646141  1.417558  0.223323  0.255208
# 5    12  0.265203  0.358887  18.286731  2.419269  0.329581  0.354292
# 6    24  0.309019  0.441106  25.582014  4.769990  0.402028  0.455990
#
#         A12       A14       A16
# 0  0.206955  0.176743  0.221800
# 1  0.222077  0.174629  0.219759
# 2  0.279376  0.216705  0.254993
# 3  0.253843  0.201709  0.242156
# 4  0.230146  0.182403  0.204886
# 5  0.234034  0.199308  0.220831
# 6  0.299149  0.205729  0.301660

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_max_A115['time'],df_max_A115['A3'],yerr=df_max_SEM['A3'],fmt='-o',color='dimgrey',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A5'],yerr=df_max_SEM['A5'],fmt='-o',color='orange',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A7'],yerr=df_max_SEM['A7'],fmt='-o',color='blue',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A8'],yerr=df_max_SEM['A8'],fmt='-o',color='rebeccapurple',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A9'],yerr=df_max_SEM['A9'],fmt='-o',color='hotpink',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A12'],yerr=df_max_SEM['A12'],fmt='-o',color='teal',markersize=6)

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(2.4, 28.5, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 28.5, 'A', ha='center', va='bottom',color='dimgrey',fontsize=18)
ax.text(5, 28.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 28.5, 'A', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(7.2, 28.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 28.5, 'A', ha='center', va='bottom',color='blue',fontsize=18)
ax.text(9.35, 28.5, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(10.4, 28.5, 'A', ha='center', va='bottom',color='hotpink',fontsize=18)
ax.text(12.1, 28.5, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 28.5, 'A', ha='center', va='bottom',color='teal',fontsize=18)
ax.text(18.5, 28.5, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 28.5, 'GAACACAAAGCATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.8, 27.3, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.95, 27.3, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(4, 27.3, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.1, 27.3, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.15, 27.3, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.2, 27.3, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.25, 27.3, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.35, 27.3, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.4, 27.3, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.45, 27.3, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.65, 27.3, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.7, 27.3, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.65, 27.3, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.55, 27.3, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.6, 27.3, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.7, 27.3, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.85, 27.3, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.9, 27.3, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.9, 27.3, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.1, 27.3, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABEmax, HEK2',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABEmax_HEK2_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# HEK3

# %%
df_max_A115 = pd.read_csv('data/ABEmax_HEK3_A115.csv')
df_max_SEM = pd.read_csv('data/ABEmax_HEK3_A115_sem.csv')

df_max_A115
# Out:
#    time        A6        A8       A12       A15       A20
# 0     0  1.269212  0.428089  0.371310  0.173527  0.263756
# 1     1  1.155672  0.509674  0.446668  0.243659  0.295762
# 2     2  1.376101  0.416381  0.436258  0.238660  0.310053
# 3     4  1.362834  0.370709  0.370800  0.233902  0.296765
# 4     8  2.419396  0.487969  0.368316  0.223155  0.256311
# 5    12  3.095126  0.534828  0.328063  0.202774  0.292629
# 6    24  5.202955  1.026908  0.404581  0.227451  0.297213

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_max_A115['time'],df_max_A115['A6'],yerr=df_max_SEM['A6'],fmt='-o',color='darkgreen',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A8'],yerr=df_max_SEM['A8'],fmt='-o',color='rebeccapurple',markersize=6)
ax.errorbar(df_max_A115['time'],df_max_A115['A12'],yerr=df_max_SEM['A12'],fmt='-o',color='teal',markersize=6)

ax.set_ylim([-0.5,5.5])
ax.set_yticks([0,1,2,3,4,5])
ax.set_yticklabels([0,1,2,3,4,5],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(3.8, 5.8, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 5.8, 'A', ha='center', va='bottom',color='darkgreen',fontsize=18)
ax.text(8.3, 5.8, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 5.8, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(11.5, 5.8, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 5.8, 'A', ha='center', va='bottom',color='teal',fontsize=18)
ax.text(18.7, 5.8, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 5.8, 'GGCCCAGACTGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.5, 5.5, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.75, 5.5, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.85, 5.5, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5, 5.5, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.1, 5.5, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.15, 5.5, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.2, 5.5, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.33, 5.5, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.5, 5.5, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.5, 5.5, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.55, 5.5, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.7, 5.5, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.8, 5.5, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.9, 5.5, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.05, 5.5, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.15, 5.5, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.3, 5.5, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.3, 5.5, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.45, 5.5, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.6, 5.5, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABEmax, HEK3',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABEmax_HEK3_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # 4C) ciABE8e time courses

# %% [markdown]
# ABE9

# %%
df_8e_A115 = pd.read_csv('data/ABE8e_ABE9_A115.csv')
df_8e_SEM = pd.read_csv('data/ABE8e_ABE9_A115_sem.csv')

df_8e_A115
# Out:
#    time        A2        A3        A5        A8        A9       A12       A14  \
# 0     0  0.337585  0.325968  0.424606  0.245636  0.263238  0.225136  0.224768
# 1     1  0.345904  0.346798  0.480235  0.243275  0.257801  0.195307  0.208758
# 2     2  0.343932  0.347827  1.205199  0.328370  0.283953  0.230259  0.208272
# 3     4  0.382242  0.392072  2.425429  0.757077  0.317237  0.266353  0.253730
# 4     8  0.342075  0.513488  4.157850  1.739999  0.407996  0.324482  0.359796
# 5    12  0.388229  0.664801  5.460409  2.689187  0.549937  0.470124  0.599723
# 6    24  0.380875  0.857077  6.796931  3.804313  0.739685  0.631745  0.634645
#
#         A16
# 0  0.271493
# 1  0.257989
# 2  0.275175
# 3  0.312515
# 4  0.268912
# 5  0.316365
# 6  0.270295

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_8e_A115['time'],df_8e_A115['A3'],yerr=df_8e_SEM['A3'],fmt='-o',color='dimgrey',mfc='dimgrey',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A5'],yerr=df_8e_SEM['A5'],fmt='-o',color='orange',mfc='orange',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A8'],yerr=df_8e_SEM['A8'],fmt='-o',color='rebeccapurple',mfc='rebeccapurple',markersize=6)

ax.set_ylim([-0.5,8.5])
ax.set_yticks([0,2,4,6,8])
ax.set_yticklabels([0,2,4,6,8],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(2.3, 9, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 9, 'A', ha='center', va='bottom',color='dimgrey',fontsize=18)
ax.text(5, 9, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 9, 'A', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(7.7, 9, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 9, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(16.4, 9, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 9, 'GAAGACCAAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.8, 8.6, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.9, 8.6, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.9, 8.6, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.05, 8.6, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.15, 8.6, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.25, 8.6, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.35, 8.6, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.45, 8.6, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.45, 8.6, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.55, 8.6, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.73, 8.6, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.8, 8.6, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.75, 8.6, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.63, 8.6, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.75, 8.6, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.85, 8.6, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.95, 8.6, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20, 8.6, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.1, 8.6, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.25, 8.6, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABE8e, ABE9',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABE8e_ABE9_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# ABE16

# %%
df_8e_A115 = pd.read_csv('data/ABE8e_ABE16_A115.csv')
df_8e_SEM = pd.read_csv('data/ABE8e_ABE16_A115_sem.csv')

df_8e_A115
# Out:
#    time         A4         A5         A7        A8        A9       A12  \
# 0     0   1.210792   1.309598   1.077149  0.247710  0.161491  0.230977
# 1     1   1.325029   1.456716   1.250422  0.242401  0.201252  0.243774
# 2     2   1.690032   1.943196   1.649984  0.314439  0.228471  0.310285
# 3     4   3.139716   3.476515   3.243167  0.478232  0.255185  0.438040
# 4     8   7.600295   7.924035   7.744459  1.503315  0.496115  1.251014
# 5    12  11.693941  11.820852  11.818525  2.956950  0.990326  2.445718
# 6    24  20.067246  20.323133  20.249936  6.901535  2.410540  4.928608
#
#         A14       A16       A17
# 0  0.140815  0.140243  0.148194
# 1  0.153830  0.136474  0.130299
# 2  0.217810  0.159844  0.177316
# 3  0.201134  0.166707  0.143383
# 4  0.329451  0.150878  0.140850
# 5  0.576592  0.165365  0.158898
# 6  1.123073  0.124895  0.111232

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_8e_A115['time'],df_8e_A115['A4'],yerr=df_8e_SEM['A4'],fmt='-o',color='red',mfc='red',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A5'],yerr=df_8e_SEM['A5'],fmt='-o',color='orange',mfc='orange',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A7'],yerr=df_8e_SEM['A7'],fmt='-o',color='blue',mfc='blue',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A8'],yerr=df_8e_SEM['A8'],fmt='-o',color='rebeccapurple',mfc='rebeccapurple',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A9'],yerr=df_8e_SEM['A9'],fmt='-o',color='hotpink',mfc='hotpink',markersize=6)

ax.set_ylim([-0.5,22])
ax.set_yticks([0,5,10,15,20])
ax.set_yticklabels([0,5,10,15,20],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(3.5, 23.3, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 23.3, 'A', ha='center', va='bottom',color='red',fontsize=18)
ax.text(6.8, 23.3, 'A', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(7.7, 23.3, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 23.3, 'A', ha='center', va='bottom',color='blue',fontsize=18)
ax.text(9.5, 23.3, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(10.6, 23.3, 'A', ha='center', va='bottom',color='hotpink',fontsize=18)
ax.text(16.6, 23.3, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 23.3, 'GGGAATAAATCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(2.25, 22.1, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.5, 22.1, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(4.65, 22.1, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.75, 22.1, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.85, 22.1, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.75, 22.1, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.55, 22.1, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.55, 22.1, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.65, 22.1, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.55, 22.1, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.55, 22.1, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.55, 22.1, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.5, 22.1, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.45, 22.1, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.45, 22.1, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.5, 22.1, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.5, 22.1, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.5, 22.1, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.5, 22.1, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.6, 22.1, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABE8e, ABE16',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABE8e_ABE16_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# HEK2

# %%
df_8e_A115 = pd.read_csv('data/ABE8e_HEK2_A115.csv')
df_8e_SEM = pd.read_csv('data/ABE8e_HEK2_A115_sem.csv')

df_8e_A115
# Out:
#    time        A2        A3         A5         A7        A8        A9  \
# 0     0  0.279252  0.406515   1.656360   1.315677  0.308014  0.296124
# 1     1  0.279921  0.418430   2.478236   1.607257  0.295688  0.260684
# 2     2  0.322302  0.515223   3.265759   1.973740  0.408584  0.326544
# 3     4  0.268516  0.604454   5.674007   4.317458  0.458116  0.306039
# 4     8  0.308158  1.046737  10.910709   9.792059  0.925638  0.524698
# 5    12  0.308992  1.775852  14.419642  13.503357  1.624693  0.828982
# 6    24  0.347113  3.573625  21.874337  21.029667  3.256770  1.478504
#
#         A12       A14       A16
# 0  0.325275  0.224044  0.218445
# 1  0.306997  0.203739  0.217131
# 2  0.384459  0.223835  0.241832
# 3  0.412655  0.231854  0.235253
# 4  0.692824  0.259867  0.237226
# 5  1.041226  0.341573  0.235828
# 6  2.034707  0.452955  0.230747

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_8e_A115['time'],df_8e_A115['A3'],yerr=df_8e_SEM['A3'],fmt='-o',color='dimgrey',mfc='dimgrey',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A5'],yerr=df_8e_SEM['A5'],fmt='-o',color='orange',mfc='orange',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A7'],yerr=df_8e_SEM['A7'],fmt='-o',color='blue',mfc='blue',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A8'],yerr=df_8e_SEM['A8'],fmt='-o',color='rebeccapurple',mfc='rebeccapurple',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A9'],yerr=df_8e_SEM['A9'],fmt='-o',color='hotpink',mfc='hotpink',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A12'],yerr=df_8e_SEM['A12'],fmt='-o',color='teal',mfc='teal',markersize=6)

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(2.4, 28.5, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 28.5, 'A', ha='center', va='bottom',color='dimgrey',fontsize=18)
ax.text(5, 28.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 28.5, 'A', ha='center', va='bottom',color='orange',fontsize=18)
ax.text(7.2, 28.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 28.5, 'A', ha='center', va='bottom',color='blue',fontsize=18)
ax.text(9.35, 28.5, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(10.4, 28.5, 'A', ha='center', va='bottom',color='hotpink',fontsize=18)
ax.text(12.1, 28.5, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 28.5, 'A', ha='center', va='bottom',color='teal',fontsize=18)
ax.text(18.5, 28.5, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 28.5, 'GAACACAAAGCATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.8, 27.3, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.95, 27.3, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(4, 27.3, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5.1, 27.3, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.15, 27.3, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.2, 27.3, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.25, 27.3, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.35, 27.3, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.4, 27.3, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.45, 27.3, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.65, 27.3, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.7, 27.3, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.65, 27.3, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.55, 27.3, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(16.6, 27.3, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.7, 27.3, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.85, 27.3, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.9, 27.3, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.9, 27.3, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.1, 27.3, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABE8e, HEK2',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABE8e_HEK2_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# HEK3

# %%
df_8e_A115 = pd.read_csv('data/ABE8e_HEK3_A115.csv')
df_8e_SEM = pd.read_csv('data/ABE8e_HEK3_A115_sem.csv')

df_8e_A115
# Out:
#    time         A6         A8       A12       A15       A20
# 0     0   9.933375   3.152898  0.616803  0.196632  0.277655
# 1     1  11.769623   3.873827  0.721224  0.251806  0.267213
# 2     2  12.673707   4.027523  0.813628  0.252688  0.266144
# 3     4  14.869745   5.243385  0.831712  0.226905  0.267852
# 4     8  17.494345   9.277625  1.359013  0.294345  0.303909
# 5    12  17.851627  10.890649  1.581350  0.366579  0.312106
# 6    24  24.171504  19.631741  3.176983  0.489794  0.279839

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_8e_A115['time'],df_8e_A115['A6'],yerr=df_8e_SEM['A6'],fmt='-o',color='darkgreen',mfc='darkgreen',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A8'],yerr=df_8e_SEM['A8'],fmt='-o',color='rebeccapurple',mfc='rebeccapurple',markersize=6)
ax.errorbar(df_8e_A115['time'],df_8e_A115['A12'],yerr=df_8e_SEM['A12'],fmt='-o',color='teal',mfc='teal',markersize=6)

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

ax.text(3.8, 28.5, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 28.5, 'A', ha='center', va='bottom',color='darkgreen',fontsize=18)
ax.text(8.3, 28.5, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 28.5, 'A', ha='center', va='bottom',color='rebeccapurple',fontsize=18)
ax.text(11.5, 28.5, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 28.5, 'A', ha='center', va='bottom',color='teal',fontsize=18)
ax.text(18.7, 28.5, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 28.5, 'GGCCCAGACTGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.text(1.5, 27.3, '1',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(2.75, 27.3, '2',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(3.85, 27.3, '3',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(5, 27.3, '4',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(6.1, 27.3, '5',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(7.15, 27.3, '6',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(8.2, 27.3, '7',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(9.33, 27.3, '8',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(10.5, 27.3, '9',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(11.5, 27.3, '10',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(12.55, 27.3, '11',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(13.7, 27.3, '12',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(14.8, 27.3, '13',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(15.9, 27.3, '14',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(17.05, 27.3, '15',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(18.15, 27.3, '16',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(19.3, 27.3, '17',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(20.3, 27.3, '18',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(21.45, 27.3, '19',ha='center', va='bottom',color='silver',fontsize=10)
ax.text(22.6, 27.3, '20',ha='center', va='bottom',color='silver',fontsize=10)

ax.set_title('ciABE8e, HEK3',fontsize=20,pad=30)

plt.savefig('ExportedPlots/ABE8e_HEK3_nucleotide_timecourse_20220208.svg',dpi=300,bbox_inches='tight')
