# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

plt.rcParams.update({'font.family':'arial'})

# %matplotlib inline

# %% [markdown]
# # ABE9

# %%
df_A115 = pd.read_csv('Data/BE4max_ABE9_A115.csv')
df_A115_SEM = pd.read_csv('Data/BE4max_ABE9_A115_sem.csv')

df_DMSO = pd.read_csv('Data/BE4max_ABE9_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/BE4max_ABE9_DMSO_sem.csv')

df_A115
# Out:
#    time        C6        C7       C17       C20
# 0     0  0.106696  0.104548  0.048108  0.175950
# 1     1  0.080213  0.078356  0.044346  0.125959
# 2     2  0.132439  0.125962  0.054639  0.152943
# 3     4  0.409641  0.390562  0.050433  0.162707
# 4     8  0.785253  0.787527  0.046692  0.133680
# 5    12  1.181045  1.176583  0.058528  0.138829
# 6    24  1.937328  1.925065  0.054012  0.146342

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C6'],yerr=df_DMSO_SEM['C6'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C6'],yerr=df_A115_SEM['C6'],fmt='-o',color='black')

ax.set_ylim([-0.2,2.2])
ax.set_yticks([0,0.5,1,1.5,2])
ax.set_yticklabels([0,0.5,1,1.5,2],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(4, 2.2, 'GAAGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 2.2, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(8.3, 2.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(15.8, 2.2, 'AAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 2.2, 'GAAGACCAAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_ABE9_C6_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C7'],yerr=df_DMSO_SEM['C7'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C7'],yerr=df_A115_SEM['C7'],fmt='-o',color='black')

ax.set_ylim([-0.2,2.2])
ax.set_yticks([0,0.5,1,1.5,2])
ax.set_yticklabels([0,0.5,1,1.5,2],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(4, 2.2, 'GAAGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 2.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.3, 2.2, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(15.8, 2.2, 'AAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)
#ax.text(12, 2.2, 'GAAGACCAAGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_ABE9_C7_20221002.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # EMX1

# %%
df_A115 = pd.read_csv('Data/BE4max_EMX1_A115.csv')
df_A115_SEM = pd.read_csv('Data/BE4max_EMX1_A115_sem.csv')

df_DMSO = pd.read_csv('Data/BE4max_EMX1_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/BE4max_EMX1_DMSO_sem.csv')

df_A115
# Out:
#    time         C5        C6
# 0     0   0.099162  0.145475
# 1     1   0.190589  0.184389
# 2     2   0.419613  0.255783
# 3     4   1.408131  0.984705
# 4     8   3.565656  2.949746
# 5    12   6.025124  5.132520
# 6    24  10.168713  8.892265

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C5'],yerr=df_DMSO_SEM['C5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C5'],yerr=df_A115_SEM['C5'],fmt='-o',color='black')

ax.set_ylim([-0.5,11])
ax.set_yticks([0,2,4,6,8,10])
ax.set_yticklabels([0,2,4,6,8,10],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.2, 11, 'GAGT', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.9, 11, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(7, 11, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(15.3, 11, 'GAGCAGAAGAAGAA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, EMX1',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_EMX1_C5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C6'],yerr=df_DMSO_SEM['C6'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C6'],yerr=df_A115_SEM['C6'],fmt='-o',color='black')

ax.set_ylim([-0.5,11])
ax.set_yticks([0,2,4,6,8,10])
ax.set_yticklabels([0,2,4,6,8,10],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.2, 11, 'GAGT', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.9, 11, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7, 11, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(15.3, 11, 'GAGCAGAAGAAGAA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, EMX1',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_EMX1_C6_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # HEK2

# %%
df_A115 = pd.read_csv('Data/BE4max_HEK2_A115.csv')
df_A115_SEM = pd.read_csv('Data/BE4max_HEK2_A115_sem.csv')

df_DMSO = pd.read_csv('Data/BE4max_HEK2_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/BE4max_HEK2_DMSO_sem.csv')

df_A115
# Out:
#    time         C4         C6       C11       C17       C20
# 0     0   0.156617   0.291003  0.129016  0.035420  0.268163
# 1     1   0.166675   0.414032  0.105082  0.055344  0.248275
# 2     2   0.310742   1.099354  0.128074  0.056569  0.255642
# 3     4   1.116808   3.564691  0.134052  0.054385  0.258071
# 4     8   4.402116   8.955606  0.128891  0.059238  0.239508
# 5    12   6.979514  12.163620  0.135689  0.060570  0.268978
# 6    24  12.421269  19.128249  0.134785  0.048448  0.251045

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C4'],yerr=df_DMSO_SEM['C4'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C4'],yerr=df_A115_SEM['C4'],fmt='-o',color='black')

ax.set_ylim([-0.5,20.5])
ax.set_yticks([0,5,10,15,20])
ax.set_yticklabels([0,5,10,15,20],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3, 20.5, 'GAA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.1, 20.5, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(6.2, 20.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 20.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(15.2, 20.5, 'AAAGCATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_HEK2_C4_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C6'],yerr=df_DMSO_SEM['C6'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C6'],yerr=df_A115_SEM['C6'],fmt='-o',color='black')

ax.set_ylim([-0.5,20.5])
ax.set_yticks([0,5,10,15,20])
ax.set_yticklabels([0,5,10,15,20],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3, 20.5, 'GAA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.1, 20.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.2, 20.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 20.5, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(15.2, 20.5, 'AAAGCATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_HEK2_C6_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # HEK3

# %%
df_A115 = pd.read_csv('Data/BE4max_HEK3_A115.csv')
df_A115_SEM = pd.read_csv('Data/BE4max_HEK3_A115_sem.csv')

df_DMSO = pd.read_csv('Data/BE4max_HEK3_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/BE4max_HEK3_DMSO_sem.csv')

df_A115
# Out:
#    time        C3         C4         C5        C9       C14       C16
# 0     0  0.204039   0.499274   0.888237  0.163390  0.276704  0.146986
# 1     1  0.135013   0.504682   0.997594  0.146977  0.202027  0.128888
# 2     2  0.156356   0.675374   1.388417  0.151426  0.235415  0.132128
# 3     4  0.185284   1.598684   3.610869  0.360078  0.185108  0.112804
# 4     8  0.326116   5.479565   9.358634  0.882266  0.251817  0.152833
# 5    12  0.371317   9.377924  13.452151  1.575887  0.219266  0.145055
# 6    24  0.667873  21.441333  27.397161  3.775435  0.236898  0.173432

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C3'],yerr=df_DMSO_SEM['C3'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C3'],yerr=df_A115_SEM['C3'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.1, 1.2, 'GG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.8, 1.2, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(4.9, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 1.2, 'AGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(17.1, 1.2, 'TGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_HEK3_C3_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C4'],yerr=df_DMSO_SEM['C4'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C4'],yerr=df_A115_SEM['C4'],fmt='-o',color='black')

ax.set_ylim([-0.5,30])
ax.set_yticks([0,5,10,15,20,25,30])
ax.set_yticklabels([0,5,10,15,20,25,30],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.1, 30, 'GG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.8, 30, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4.9, 30, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(6, 30, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 30, 'AGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 30, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(17.1, 30, 'TGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_HEK3_C4_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C5'],yerr=df_DMSO_SEM['C5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C5'],yerr=df_A115_SEM['C5'],fmt='-o',color='black')

ax.set_ylim([-0.5,30])
ax.set_yticks([0,5,10,15,20,25,30])
ax.set_yticklabels([0,5,10,15,20,25,30],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.1, 30, 'GG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.8, 30, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4.9, 30, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6, 30, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(8.2, 30, 'AGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 30, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(17.1, 30, 'TGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_HEK3_C5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['C9'],yerr=df_DMSO_SEM['C9'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['C9'],yerr=df_A115_SEM['C9'],fmt='-o',color='black')

ax.set_ylim([-0.5,5.5])
ax.set_yticks([0,1,2,3,4,5])
ax.set_yticklabels([0,1,2,3,4,5],fontsize=16)
ax.set_ylabel('C > T editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.1, 5.5, 'GG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.8, 5.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4.9, 5.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6, 5.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 5.5, 'AGA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 5.5, 'C', ha='center', va='bottom',color='black',fontsize=18)
ax.text(17.1, 5.5, 'TGAGCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciBE4max, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/BE4max_HEK3_C9_20211109.svg',dpi=300,bbox_inches='tight')
