# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

plt.rcParams.update({'font.family':'arial'})

# %matplotlib inline

# %% [markdown]
# # ABE9

# %%
df_A115 = pd.read_csv('Data/ABEmax_ABE9_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABEmax_ABE9_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABEmax_ABE9_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABEmax_ABE9_DMSO_sem.csv')

df_A115
# Out:
#    time        A2        A3        A5        A8        A9       A12       A14  \
# 0     0  0.358569  0.354975  0.395391  0.233220  0.265664  0.228197  0.219255
# 1     1  0.350241  0.368490  0.451735  0.237047  0.250999  0.225024  0.227754
# 2     2  0.343201  0.337960  0.762624  0.236606  0.272299  0.225425  0.217741
# 3     4  0.319464  0.320110  1.456314  0.213129  0.235157  0.189793  0.212592
# 4     8  0.335909  0.301736  3.462152  0.232317  0.249113  0.194135  0.183249
# 5    12  0.388636  0.373942  4.522228  0.261204  0.307354  0.240697  0.251807
# 6    24  0.346727  0.326956  7.189869  0.345514  0.306686  0.228406  0.208398
#
#         A16
# 0  0.267620
# 1  0.305035
# 2  0.316549
# 3  0.279489
# 4  0.252264
# 5  0.303891
# 6  0.275031

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A3'],yerr=df_DMSO_SEM['A3'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A3'],yerr=df_A115_SEM['A3'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.3, 1.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(5, 1.2, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 1.2, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.4, 1.2, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_ABE9_A3_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A5'],yerr=df_DMSO_SEM['A5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A5'],yerr=df_A115_SEM['A5'],fmt='-o',color='black')

ax.set_ylim([-0.5,8.5])
ax.set_yticks([0,2,4,6,8])
ax.set_yticklabels([0,2,4,6,8],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.3, 8.5, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 8.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 8.5, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 8.5, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(7.7, 8.5, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 8.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.4, 8.5, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_ABE9_A5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.3, 1.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(3.9, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 1.2, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 1.2, 'CC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.3, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(16.4, 1.2, 'AGGATAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, ABE9',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_ABE9_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # ABE16

# %%
df_A115 = pd.read_csv('Data/ABEmax_ABE16_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABEmax_ABE16_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABEmax_ABE16_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABEmax_ABE16_DMSO_sem.csv')

df_A115
# Out:
#    time        A4         A5         A7        A8        A9       A12  \
# 0     0  0.279726   2.319232   0.786641  0.168519  0.153396  0.168881
# 1     1  0.292358   2.429489   0.662951  0.177479  0.143018  0.169173
# 2     2  0.370645   4.579123   1.234754  0.173311  0.127524  0.167055
# 3     4  0.431492   8.496818   1.794260  0.189206  0.180145  0.185136
# 4     8  0.870147  14.207716   5.434250  0.298291  0.234171  0.183785
# 5    12  1.696255  17.583705   9.959812  0.389748  0.305014  0.242809
# 6    24  4.623897  24.491393  19.594813  0.755758  0.611430  0.248907
#
#         A14       A16       A17
# 0  0.168147  0.137147  0.147051
# 1  0.153183  0.117268  0.123067
# 2  0.163179  0.124245  0.120636
# 3  0.163510  0.144350  0.126696
# 4  0.146995  0.157322  0.131004
# 5  0.160207  0.146182  0.129592
# 6  0.194270  0.125895  0.125887

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A4'],yerr=df_DMSO_SEM['A4'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A4'],yerr=df_A115_SEM['A4'],fmt='-o',color='black')

ax.set_ylim([-0.2,5.2])
ax.set_yticks([0,1,2,3,4,5])
ax.set_yticklabels([0,1,2,3,4,5],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 5.2, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 5.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(6.8, 5.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 5.2, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 5.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.5, 5.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.6, 5.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 5.2, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_ABE16_A4_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A5'],yerr=df_DMSO_SEM['A5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A5'],yerr=df_A115_SEM['A5'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 27, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.8, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(7.7, 27, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.6, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 27, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_ABE16_A5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A7'],yerr=df_DMSO_SEM['A7'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A7'],yerr=df_A115_SEM['A7'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 27, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.8, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 27, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(9.5, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.6, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 27, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_ABE16_A7_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.5, 1.2, 'GGG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5.7, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.8, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.7, 1.2, 'T', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.5, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.5, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(10.6, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(16.6, 1.2, 'TCATAGAATCC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, ABE16',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_ABE16_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # HEK2

# %%
df_A115 = pd.read_csv('Data/ABEmax_HEK2_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABEmax_HEK2_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABEmax_HEK2_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABEmax_HEK2_DMSO_sem.csv')

df_A115
# Out:
#    time        A2        A3         A5        A7        A8        A9  \
# 0     0  0.280169  0.307123   2.909596  0.444721  0.229205  0.256242
# 1     1  0.257553  0.303324   3.706076  0.449062  0.219951  0.233345
# 2     2  0.331825  0.379255   5.475038  0.528234  0.296191  0.315258
# 3     4  0.290838  0.341137   7.590695  0.618457  0.255224  0.265429
# 4     8  0.255478  0.311876  13.646141  1.417558  0.223323  0.255208
# 5    12  0.265203  0.358887  18.286731  2.419269  0.329581  0.354292
# 6    24  0.309019  0.441106  25.582014  4.769990  0.402028  0.455990
#
#         A12       A14       A16
# 0  0.206955  0.176743  0.221800
# 1  0.222077  0.174629  0.219759
# 2  0.279376  0.216705  0.254993
# 3  0.253843  0.201709  0.242156
# 4  0.230146  0.182403  0.204886
# 5  0.234034  0.199308  0.220831
# 6  0.299149  0.205729  0.301660

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A3'],yerr=df_DMSO_SEM['A3'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A3'],yerr=df_A115_SEM['A3'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 1.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(5, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 1.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 1.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK2_A3_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A5'],yerr=df_DMSO_SEM['A5'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A5'],yerr=df_A115_SEM['A5'],fmt='-o',color='black')

ax.set_ylim([-0.5,27])
ax.set_yticks([0,5,10,15,20,25])
ax.set_yticklabels([0,5,10,15,20,25],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 27, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 27, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 27, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(7.2, 27, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 27, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 27, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 27, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK2_A5_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A7'],yerr=df_DMSO_SEM['A7'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A7'],yerr=df_A115_SEM['A7'],fmt='-o',color='black')

ax.set_ylim([-0.5,5.5])
ax.set_yticks([0,1,2,3,4,5])
ax.set_yticklabels([0,1,2,3,4,5],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 5.5, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 5.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 5.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 5.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 5.5, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 5.5, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(9.35, 5.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 5.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 5.5, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 5.5, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 5.5, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK2_A7_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 1.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(10.4, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 1.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 1.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK2_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A9'],yerr=df_DMSO_SEM['A9'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A9'],yerr=df_A115_SEM['A9'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 1.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(12.1, 1.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.5, 1.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK2_A9_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A12'],yerr=df_DMSO_SEM['A12'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A12'],yerr=df_A115_SEM['A12'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(2.4, 1.2, 'GA', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(4, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(5, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(6.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.2, 1.2, 'C', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.2, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(10.4, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(12.1, 1.2, 'GC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.7, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(18.5, 1.2, 'TAGACTGC', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK2',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK2_A12_20211109.svg',dpi=300,bbox_inches='tight')

# %% [markdown]
# # HEK3

# %%
df_A115 = pd.read_csv('Data/ABEmax_HEK3_A115.csv')
df_A115_SEM = pd.read_csv('Data/ABEmax_HEK3_A115_sem.csv')

df_DMSO = pd.read_csv('Data/ABEmax_HEK3_DMSO.csv')
df_DMSO_SEM = pd.read_csv('Data/ABEmax_HEK3_DMSO_sem.csv')

df_A115
# Out:
#    time        A6        A8       A12       A15       A20
# 0     0  1.269212  0.428089  0.371310  0.173527  0.263756
# 1     1  1.155672  0.509674  0.446668  0.243659  0.295762
# 2     2  1.376101  0.416381  0.436258  0.238660  0.310053
# 3     4  1.362834  0.370709  0.370800  0.233902  0.296765
# 4     8  2.419396  0.487969  0.368316  0.223155  0.256311
# 5    12  3.095126  0.534828  0.328063  0.202774  0.292629
# 6    24  5.202955  1.026908  0.404581  0.227451  0.297213

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A6'],yerr=df_DMSO_SEM['A6'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A6'],yerr=df_A115_SEM['A6'],fmt='-o',color='black')

ax.set_ylim([-0.5,6.2])
ax.set_yticks([0,2,4,6])
ax.set_yticklabels([0,2,4,6],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.8, 6.2, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 6.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(8.3, 6.2, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 6.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(11.5, 6.2, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 6.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.7, 6.2, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK3_A6_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A8'],yerr=df_DMSO_SEM['A8'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A8'],yerr=df_A115_SEM['A8'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.8, 1.2, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.3, 1.2, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(11.5, 1.2, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(18.7, 1.2, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK3_A8_20211109.svg',dpi=300,bbox_inches='tight')

# %%
fig,ax = plt.subplots(figsize=(5.2,2.6))

ax.errorbar(df_DMSO['time'],df_DMSO['A12'],yerr=df_DMSO_SEM['A12'],fmt='-o',color='darkgrey')
ax.errorbar(df_A115['time'],df_A115['A12'],yerr=df_A115_SEM['A12'],fmt='-o',color='black')

ax.set_ylim([-0.1,1.2])
ax.set_yticks([0.0,0.4,0.8,1.2])
ax.set_yticklabels([0.0,0.4,0.8,1.2],fontsize=16)
ax.set_ylabel('A > G editing\nfrequency (%)',fontsize=18)

ax.set_xlim([-0.5,24.5])
ax.set_xticks([0,4,8,12,16,20,24])
ax.set_xticklabels([0,4,8,12,16,20,24],fontsize=16)
ax.set_xlabel('Time (hr)',fontsize=18)

ax.axhline(0,-0.5,24.5,color='lightgrey',linestyle='--')

legend_elements = [Line2D([0],[0],marker='o',color='black',label='+ A115',
                          markerfacecolor='black',markersize=6,linestyle='-'),
                   Line2D([0],[0],marker='o',color='darkgrey',label='+ DMSO',
                          markerfacecolor='darkgrey',markersize=6,linestyle='-')]
ax.legend(handles=legend_elements,bbox_to_anchor=(0.32,1.05),
          fontsize=13,frameon=False,handlelength=1.6,handletextpad=0.2)

ax.text(3.8, 1.2, 'GGCCC', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(7.1, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(8.3, 1.2, 'G', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(9.35, 1.2, 'A', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(11.5, 1.2, 'CTG', ha='center', va='bottom',color='silver',fontsize=18)
ax.text(13.65, 1.2, 'A', ha='center', va='bottom',color='black',fontsize=18)
ax.text(18.7, 1.2, 'GCACGTGA', ha='center', va='bottom',color='silver',fontsize=18)

ax.set_title('ciABEmax, HEK3',fontsize=20,pad=25)

plt.savefig('ExportedPlots/ABEmax_HEK3_A12_20211109.svg',dpi=300,bbox_inches='tight')
