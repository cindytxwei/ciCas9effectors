# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.rcParams.update({'font.family':'arial'})

from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LinearSegmentedColormap

# %matplotlib inline

# %%
df = pd.read_csv('Data/full_target/BE4max_EMX1.csv',index_col=0)

df.columns = ['G1','A2','G3','T4','C5','C6','G7','A8','G9','C10',
              'A11','G12','A13','A14','G15','A16','A17','G18','A19','A20']

df = df*100

df
# Out:
#                                 G1        A2        G3         T4         C5  \
# Batch
# 72hr_cellsonly_1          0.034897  0.039551  0.018612  99.799921   0.027918
# 72hr_cellsonly_2          0.028813  0.032655  0.011525  99.819439   0.051863
# 72hr_cellsonly_3          0.016925  0.033849  0.007520  99.793144   0.037610
# 48hr_Cas9_BE4_EMX1_1      0.013147  0.029580  0.026293  99.615460  70.623809
# 48hr_Cas9_BE4_EMX1_2      0.009290  0.018590  0.046475  99.790863  70.790538
# 48hr_Cas9_BE4_EMX1_3      0.013572  0.035287  0.013572  99.736706  70.530116
# 72hr_F22_BE4_EMX1_A115_1  0.020497  0.044721  0.013044  99.781985  33.524019
# 72hr_F22_BE4_EMX1_A115_2  0.031468  0.033566  0.018881  99.817488  33.288579
# 72hr_F22_BE4_EMX1_A115_3  0.020664  0.037571  0.015029  99.778329  33.196198
#
#                                  C6        G7        A8        G9       C10  \
# Batch
# 72hr_cellsonly_1           0.169835  0.018612  0.034897  0.018612  0.190773
# 72hr_cellsonly_2           0.121014  0.030734  0.034576  0.017288  0.186324
# 72hr_cellsonly_3           0.148561  0.024447  0.041371  0.013164  0.191812
# 48hr_Cas9_BE4_EMX1_1      69.085650  0.092027  0.042727  0.019720  0.269506
# 48hr_Cas9_BE4_EMX1_2      69.247572  0.092950  0.027885  0.013942  0.418274
# 48hr_Cas9_BE4_EMX1_3      68.969355  0.114003  0.040715  0.008140  0.306724
# 72hr_F22_BE4_EMX1_A115_1  30.209071  0.095032  0.029814  0.016770  0.216152
# 72hr_F22_BE4_EMX1_A115_2  29.627843  0.111186  0.031468  0.027272  0.226567
# 72hr_F22_BE4_EMX1_A115_3  29.831680  0.103321  0.043207  0.016907  0.240457
#
#                                A11       G12       A13       A14       G15  \
# Batch
# 72hr_cellsonly_1          0.034897  0.018612  0.034897  0.041877  0.018612
# 72hr_cellsonly_2          0.046101  0.019209  0.030734  0.040338  0.009600
# 72hr_cellsonly_3          0.041371  0.030088  0.031969  0.035730  0.007520
# 48hr_Cas9_BE4_EMX1_1      0.026293  0.019720  0.046013  0.042727  0.026293
# 48hr_Cas9_BE4_EMX1_2      0.046475  0.032532  0.009290  0.046475  0.018590
# 48hr_Cas9_BE4_EMX1_3      0.043430  0.038001  0.021715  0.046144  0.019001
# 72hr_F22_BE4_EMX1_A115_1  0.037268  0.020497  0.018634  0.035404  0.001860
# 72hr_F22_BE4_EMX1_A115_2  0.048250  0.010489  0.018881  0.044055  0.014685
# 72hr_F22_BE4_EMX1_A115_3  0.035693  0.030057  0.018786  0.046964  0.011271
#
#                                A16       A17       G18       A19       A20
# Batch
# 72hr_cellsonly_1          0.039551  0.051183  0.016286  0.055836  0.041877
# 72hr_cellsonly_2          0.026892  0.036496  0.013446  0.026892  0.030734
# 72hr_cellsonly_3          0.026327  0.048893  0.011283  0.033849  0.039491
# 48hr_Cas9_BE4_EMX1_1      0.046013  0.029580  0.029580  0.036153  0.062447
# 48hr_Cas9_BE4_EMX1_2      0.032532  0.083655  0.023237  0.046475  0.037180
# 48hr_Cas9_BE4_EMX1_3      0.021715  0.024429  0.021715  0.038001  0.029858
# 72hr_F22_BE4_EMX1_A115_1  0.018634  0.046584  0.011180  0.037268  0.039131
# 72hr_F22_BE4_EMX1_A115_2  0.025174  0.027272  0.018881  0.050348  0.048250
# 72hr_F22_BE4_EMX1_A115_3  0.026300  0.054478  0.015029  0.037571  0.056357

# %%
df2 = df.div(df.C5, axis=0) * 100

df2
# Out:
#                                   G1          A2         G3             T4  \
# Batch
# 72hr_cellsonly_1          125.000000  141.666667  66.666667  357475.180529
# 72hr_cellsonly_2           55.555577   62.962949  22.222308  192466.795531
# 72hr_cellsonly_3           45.000027   90.000053  19.994576  265335.317813
# 48hr_Cas9_BE4_EMX1_1        0.018615    0.041884   0.037230     141.050819
# 48hr_Cas9_BE4_EMX1_2        0.013123    0.026261   0.065651     140.966387
# 48hr_Cas9_BE4_EMX1_3        0.019243    0.050031   0.019243     141.410099
# 72hr_F22_BE4_EMX1_A115_1    0.061142    0.133400   0.038908     297.643266
# 72hr_F22_BE4_EMX1_A115_2    0.094530    0.100832   0.056718     299.855054
# 72hr_F22_BE4_EMX1_A115_3    0.062249    0.113180   0.045272     300.571558
#
#                              C5          C6         G7          A8         G9  \
# Batch
# 72hr_cellsonly_1          100.0  608.333692  66.666667  125.000000  66.666667
# 72hr_cellsonly_2          100.0  233.333462  59.259359   66.666731  33.333269
# 72hr_cellsonly_3          100.0  395.000558  65.000186  110.000213  35.000080
# 48hr_Cas9_BE4_EMX1_1      100.0   97.822040   0.130305    0.060499   0.027923
# 48hr_Cas9_BE4_EMX1_2      100.0   97.820378   0.131303    0.039391   0.019695
# 48hr_Cas9_BE4_EMX1_3      100.0   97.787100   0.161638    0.057728   0.011541
# 72hr_F22_BE4_EMX1_A115_1  100.0   90.111723   0.283475    0.088933   0.050025
# 72hr_F22_BE4_EMX1_A115_2  100.0   89.003025   0.334006    0.094530   0.081926
# 72hr_F22_BE4_EMX1_A115_3  100.0   89.864750   0.311244    0.130157   0.050931
#
#                                  C10         A11        G12         A13  \
# Batch
# 72hr_cellsonly_1          683.333692  125.000000  66.666667  125.000000
# 72hr_cellsonly_2          359.259552   88.889039  37.037051   59.259359
# 72hr_cellsonly_3          510.000479  110.000213  80.000106   85.000080
# 48hr_Cas9_BE4_EMX1_1        0.381608    0.037230   0.027923    0.065153
# 48hr_Cas9_BE4_EMX1_2        0.590861    0.065651   0.045956    0.013123
# 48hr_Cas9_BE4_EMX1_3        0.434883    0.061576   0.053879    0.030788
# 72hr_F22_BE4_EMX1_A115_1    0.644767    0.111167   0.061142    0.055583
# 72hr_F22_BE4_EMX1_A115_2    0.680615    0.144946   0.031510    0.056718
# 72hr_F22_BE4_EMX1_A115_3    0.724351    0.107521   0.090544    0.056590
#
#                                  A14        G15         A16         A17  \
# Batch
# 72hr_cellsonly_1          150.000000  66.666667  141.666667  183.333333
# 72hr_cellsonly_2           77.777885  18.510235   51.851795   70.370513
# 72hr_cellsonly_3           95.000027  19.994576   70.000160  130.000106
# 48hr_Cas9_BE4_EMX1_1        0.060499   0.037230    0.065153    0.041884
# 48hr_Cas9_BE4_EMX1_2        0.065651   0.026261    0.045956    0.118172
# 48hr_Cas9_BE4_EMX1_3        0.065425   0.026940    0.030788    0.034637
# 72hr_F22_BE4_EMX1_A115_1    0.105608   0.005548    0.055583    0.138958
# 72hr_F22_BE4_EMX1_A115_2    0.132342   0.044114    0.075624    0.081926
# 72hr_F22_BE4_EMX1_A115_3    0.141475   0.033954    0.079226    0.164111
#
#                                 G18         A19         A20
# Batch
# 72hr_cellsonly_1          58.333333  200.000000  150.000000
# 72hr_cellsonly_2          25.925897   51.851795   59.259359
# 72hr_cellsonly_3          30.000106   90.000053  105.000239
# 48hr_Cas9_BE4_EMX1_1       0.041884    0.051191    0.088421
# 48hr_Cas9_BE4_EMX1_2       0.032826    0.065651    0.052521
# 48hr_Cas9_BE4_EMX1_3       0.030788    0.053879    0.042334
# 72hr_F22_BE4_EMX1_A115_1   0.033350    0.111167    0.116725
# 72hr_F22_BE4_EMX1_A115_2   0.056718    0.151248    0.144946
# 72hr_F22_BE4_EMX1_A115_3   0.045272    0.113180    0.169770

# %%
fig, (ax1, ax2) = plt.subplots(2,1,gridspec_kw={'height_ratios':[1,9]},figsize=(8,4))

#plt.setp(ax1.get_xticklabels(), visible=False)
fig.subplots_adjust(hspace=0)

ax1.set_ylim(-0.1,0.1)
ax1.set_xlim(-0.5,19.5)
ax2.set_xlim(-0.5,19.5)

ax1.axes.yaxis.set_visible(False)
ax1.axes.xaxis.set_visible(False)

ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.setp(ax2.spines.values(), color='grey')

ref = 'GAGTCCGAGCAGAAGAAGAA'
zero = [0] * len(df)

for x,nucleotide in enumerate(ref):
    if nucleotide == 'A':
        ax1.scatter(x,0,s=450,c='mediumseagreen',marker='s')
        ax1.text(x,0, 'A', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'C':
        ax1.scatter(x,0,s=450,c='royalblue',marker='s')
        ax1.text(x,0, 'C', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'G':
        ax1.scatter(x,0,s=450,c='gold',marker='s')
        ax1.text(x,0, 'G', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'T':
        ax1.scatter(x,0,s=450,c='tomato',marker='s')
        ax1.text(x,0, 'T', ha='center',va='center',color='white',size=20)
        n = df.columns[x]
        df.drop(n,axis=1,inplace=False)
        df[n] = zero

cmap = LinearSegmentedColormap.from_list('mycmap', ['white', '#006600'])
masked_array = np.ma.masked_where(df < 0.7, df2)
cmap.set_bad(color='gainsboro')

g2 = ax2.imshow(masked_array,cmap=cmap,aspect="auto",interpolation='none',vmin=0,vmax=100)

cbar_ax = fig.add_axes([0.92, 0.12, 0.02, 0.68])
cbar = fig.colorbar(g2, cax=cbar_ax)
cbar.set_label('% of maximum\nC > T editing',fontsize=16)
cbar.ax.tick_params(labelsize=16)

ax2.set_xticks(np.arange(0, 20, 1))
ax2.set_xticklabels(np.arange(1, 21, 1), fontsize=14)
ax2.set_xticks(np.arange(-.5, 20, 1), minor=True)
ax2.set_yticks(np.arange(-.5, 9, 1), minor=True)
ax2.grid(which='minor', color='grey', linestyle='-', linewidth=0.75)

ax2.hlines([2.5,5.5], xmin=-0.5, xmax=19.5, color="black")

ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')

ytick_labels = ['','','control','','','BE4max','','','ciBE4max']
ax2.set_yticklabels(labels = ytick_labels,
                    fontsize = 16)

ax1.set_title('BE4max, EMX1', fontsize=20)

plt.savefig('ExportedPlots/20211228_BE4max_EMX1_fulltarget_heatmap.pdf',dpi=300,bbox_inches='tight')
# Out:
# /var/folders/zt/rj0vk4w576n5lb6vjzgpk8nc0000gn/T/ipykernel_18119/4019973649.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels(labels = ytick_labels,

# %%
df = pd.read_csv('Data/full_target/AncBE4max_EMX1.csv',index_col=0)

df.columns = ['G1','A2','G3','T4','C5','C6','G7','A8','G9','C10',
              'A11','G12','A13','A14','G15','A16','A17','G18','A19','A20']

df = df*100

df
# Out:
#                                 G1        A2        G3         T4         C5  \
# Batch
# 72hr_cellsonly_1          0.034897  0.039551  0.018612  99.799921   0.027918
# 72hr_cellsonly_2          0.028813  0.032655  0.011525  99.819439   0.051863
# 72hr_cellsonly_3          0.016925  0.033849  0.007520  99.793144   0.037610
# 48hr_Cas9_Anc_EMX1_1      0.011081  0.033242  0.019391  99.797778  66.924291
# 48hr_Cas9_Anc_EMX1_2      0.019089  0.038178  0.004770  99.749457  67.135937
# 48hr_Cas9_Anc_EMX1_3      0.027414  0.042175  0.018979  99.668923  70.156682
# 72hr_F22_Anc_EMX1_A115_1  0.018062  0.032840  0.003280  99.789823  24.048866
# 72hr_F22_Anc_EMX1_A115_2  0.016301  0.038715  0.014264  99.786046  23.235390
# 72hr_F22_Anc_EMX1_A115_3  0.014375  0.046718  0.017070  99.769107  23.928414
#
#                                  C6        G7        A8        G9       C10  \
# Batch
# 72hr_cellsonly_1           0.169835  0.018612  0.034897  0.018612  0.190773
# 72hr_cellsonly_2           0.121014  0.030734  0.034576  0.017288  0.186324
# 72hr_cellsonly_3           0.148561  0.024447  0.041371  0.013164  0.191812
# 48hr_Cas9_Anc_EMX1_1      65.558603  0.135738  0.027702  0.013851  0.285326
# 48hr_Cas9_Anc_EMX1_2      65.625522  0.088287  0.050109  0.026247  0.386552
# 48hr_Cas9_Anc_EMX1_3      68.522385  0.094895  0.067481  0.025305  0.297337
# 72hr_F22_Anc_EMX1_A115_1  21.896192  0.106731  0.041050  0.018062  0.251227
# 72hr_F22_Anc_EMX1_A115_2  21.228299  0.105958  0.026490  0.028527  0.281197
# 72hr_F22_Anc_EMX1_A115_3  21.871041  0.070076  0.035937  0.012578  0.235385
#
#                                A11       G12       A13       A14       G15  \
# Batch
# 72hr_cellsonly_1          0.034897  0.018612  0.034897  0.041877  0.018612
# 72hr_cellsonly_2          0.046101  0.019209  0.030734  0.040338  0.009600
# 72hr_cellsonly_3          0.041371  0.030088  0.031969  0.035730  0.007520
# 48hr_Cas9_Anc_EMX1_1      0.044323  0.027702  0.016621  0.047093  0.008310
# 48hr_Cas9_Anc_EMX1_2      0.031020  0.011931  0.016703  0.035792  0.019089
# 48hr_Cas9_Anc_EMX1_3      0.065372  0.021088  0.012653  0.046393  0.004220
# 72hr_F22_Anc_EMX1_A115_1  0.049260  0.022988  0.034482  0.034482  0.014778
# 72hr_F22_Anc_EMX1_A115_2  0.059092  0.024452  0.022414  0.042791  0.020377
# 72hr_F22_Anc_EMX1_A115_3  0.044022  0.014375  0.027851  0.038632  0.008090
#
#                                A16       A17       G18       A19       A20
# Batch
# 72hr_cellsonly_1          0.039551  0.051183  0.016286  0.055836  0.041877
# 72hr_cellsonly_2          0.026892  0.036496  0.013446  0.026892  0.030734
# 72hr_cellsonly_3          0.026327  0.048893  0.011283  0.033849  0.039491
# 48hr_Cas9_Anc_EMX1_1      0.030472  0.033242  0.013851  0.027702  0.027702
# 48hr_Cas9_Anc_EMX1_2      0.047722  0.028633  0.011931  0.047722  0.047722
# 48hr_Cas9_Anc_EMX1_3      0.018979  0.046393  0.014761  0.061154  0.031632
# 72hr_F22_Anc_EMX1_A115_1  0.036124  0.027914  0.018062  0.045976  0.047618
# 72hr_F22_Anc_EMX1_A115_2  0.032602  0.065205  0.020377  0.057054  0.059092
# 72hr_F22_Anc_EMX1_A115_3  0.025156  0.052108  0.014375  0.043124  0.025156

# %%
df2 = df.div(df.C5, axis=0) * 100

df2
# Out:
#                                   G1          A2         G3             T4  \
# Batch
# 72hr_cellsonly_1          125.000000  141.666667  66.666667  357475.180529
# 72hr_cellsonly_2           55.555577   62.962949  22.222308  192466.795531
# 72hr_cellsonly_3           45.000027   90.000053  19.994576  265335.317813
# 48hr_Cas9_Anc_EMX1_1        0.016557    0.049671   0.028975     149.120411
# 48hr_Cas9_Anc_EMX1_2        0.028433    0.056867   0.007105     148.578334
# 48hr_Cas9_Anc_EMX1_3        0.039075    0.060116   0.027052     142.066188
# 72hr_F22_Anc_EMX1_A115_1    0.075106    0.136556   0.013639     414.946060
# 72hr_F22_Anc_EMX1_A115_2    0.070157    0.166623   0.061387     429.457160
# 72hr_F22_Anc_EMX1_A115_3    0.060074    0.195239   0.071337     416.948262
#
#                              C5          C6         G7          A8         G9  \
# Batch
# 72hr_cellsonly_1          100.0  608.333692  66.666667  125.000000  66.666667
# 72hr_cellsonly_2          100.0  233.333462  59.259359   66.666731  33.333269
# 72hr_cellsonly_3          100.0  395.000558  65.000186  110.000213  35.000080
# 48hr_Cas9_Anc_EMX1_1      100.0   97.959353   0.202823    0.041392   0.020696
# 48hr_Cas9_Anc_EMX1_2      100.0   97.750213   0.131504    0.074638   0.039096
# 48hr_Cas9_Anc_EMX1_3      100.0   97.670504   0.135261    0.096186   0.036070
# 72hr_F22_Anc_EMX1_A115_1  100.0   91.048751   0.443807    0.170695   0.075106
# 72hr_F22_Anc_EMX1_A115_2  100.0   91.361922   0.456020    0.114005   0.122775
# 72hr_F22_Anc_EMX1_A115_3  100.0   91.401968   0.292859    0.150184   0.052564
#
#                                  C10         A11        G12         A13  \
# Batch
# 72hr_cellsonly_1          683.333692  125.000000  66.666667  125.000000
# 72hr_cellsonly_2          359.259552   88.889039  37.037051   59.259359
# 72hr_cellsonly_3          510.000479  110.000213  80.000106   85.000080
# 48hr_Cas9_Anc_EMX1_1        0.426342    0.066228   0.041392    0.024836
# 48hr_Cas9_Anc_EMX1_2        0.575775    0.046204   0.017771    0.024879
# 48hr_Cas9_Anc_EMX1_3        0.423818    0.093180   0.030058    0.018035
# 72hr_F22_Anc_EMX1_A115_1    1.044654    0.204834   0.095589    0.143384
# 72hr_F22_Anc_EMX1_A115_2    1.210208    0.254319   0.105236    0.096466
# 72hr_F22_Anc_EMX1_A115_3    0.983705    0.183975   0.060074    0.116393
#
#                                  A14        G15         A16         A17  \
# Batch
# 72hr_cellsonly_1          150.000000  66.666667  141.666667  183.333333
# 72hr_cellsonly_2           77.777885  18.510235   51.851795   70.370513
# 72hr_cellsonly_3           95.000027  19.994576   70.000160  130.000106
# 48hr_Cas9_Anc_EMX1_1        0.070367   0.012417    0.045532    0.049671
# 48hr_Cas9_Anc_EMX1_2        0.053312   0.028433    0.071083    0.042650
# 48hr_Cas9_Anc_EMX1_3        0.066128   0.006015    0.027052    0.066128
# 72hr_F22_Anc_EMX1_A115_1    0.143384   0.061450    0.150212    0.116073
# 72hr_F22_Anc_EMX1_A115_2    0.184162   0.087696    0.140314    0.280628
# 72hr_F22_Anc_EMX1_A115_3    0.161448   0.033809    0.105129    0.217767
#
#                                 G18         A19         A20
# Batch
# 72hr_cellsonly_1          58.333333  200.000000  150.000000
# 72hr_cellsonly_2          25.925897   51.851795   59.259359
# 72hr_cellsonly_3          30.000106   90.000053  105.000239
# 48hr_Cas9_Anc_EMX1_1       0.020696    0.041392    0.041392
# 48hr_Cas9_Anc_EMX1_2       0.017771    0.071083    0.071083
# 48hr_Cas9_Anc_EMX1_3       0.021041    0.087168    0.045087
# 72hr_F22_Anc_EMX1_A115_1   0.075106    0.191179    0.198006
# 72hr_F22_Anc_EMX1_A115_2   0.087696    0.245550    0.254319
# 72hr_F22_Anc_EMX1_A115_3   0.060074    0.180221    0.105129

# %%
fig, (ax1, ax2) = plt.subplots(2,1,gridspec_kw={'height_ratios':[1,9]},figsize=(8,4))

#plt.setp(ax1.get_xticklabels(), visible=False)
fig.subplots_adjust(hspace=0)

ax1.set_ylim(-0.1,0.1)
ax1.set_xlim(-0.5,19.5)
ax2.set_xlim(-0.5,19.5)

ax1.axes.yaxis.set_visible(False)
ax1.axes.xaxis.set_visible(False)

ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.setp(ax2.spines.values(), color='grey')

ref = 'GAGTCCGAGCAGAAGAAGAA'
zero = [0] * len(df)

for x,nucleotide in enumerate(ref):
    if nucleotide == 'A':
        ax1.scatter(x,0,s=450,c='mediumseagreen',marker='s')
        ax1.text(x,0, 'A', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'C':
        ax1.scatter(x,0,s=450,c='royalblue',marker='s')
        ax1.text(x,0, 'C', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'G':
        ax1.scatter(x,0,s=450,c='gold',marker='s')
        ax1.text(x,0, 'G', ha='center',va='center',color='white',size=20)
    elif nucleotide == 'T':
        ax1.scatter(x,0,s=450,c='tomato',marker='s')
        ax1.text(x,0, 'T', ha='center',va='center',color='white',size=20)
        n = df.columns[x]
        df.drop(n,axis=1,inplace=False)
        df[n] = zero

cmap = LinearSegmentedColormap.from_list('mycmap', ['white', '#006600'])
masked_array = np.ma.masked_where(df < 0.7, df2)
cmap.set_bad(color='gainsboro')

g2 = ax2.imshow(masked_array,cmap=cmap,aspect="auto",interpolation='none',vmin=0,vmax=100)

cbar_ax = fig.add_axes([0.92, 0.12, 0.02, 0.68])
cbar = fig.colorbar(g2, cax=cbar_ax)
cbar.set_label('% of maximum\nC > T editing',fontsize=16)
cbar.ax.tick_params(labelsize=16)

ax2.set_xticks(np.arange(0, 20, 1))
ax2.set_xticklabels(np.arange(1, 21, 1), fontsize=14)
ax2.set_xticks(np.arange(-.5, 20, 1), minor=True)
ax2.set_yticks(np.arange(-.5, 9, 1), minor=True)
ax2.grid(which='minor', color='grey', linestyle='-', linewidth=0.75)

ax2.hlines([2.5,5.5], xmin=-0.5, xmax=19.5, color="black")

ax2.xaxis.set_ticks_position('none')
ax2.yaxis.set_ticks_position('none')

ytick_labels = ['','','control','','','AncBE4max','','','ciAncBE4max']
ax2.set_yticklabels(labels = ytick_labels,
                    fontsize = 16)

ax1.set_title('AncBE4max, EMX1', fontsize=20)

plt.savefig('ExportedPlots/20211228_AncBE4max_EMX1_fulltarget_heatmap.pdf',dpi=300,bbox_inches='tight')
# Out:
# /var/folders/zt/rj0vk4w576n5lb6vjzgpk8nc0000gn/T/ipykernel_18119/1471616813.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels(labels = ytick_labels,
